# %%
import numpy as np
import math

# %%
def geodesicInfoFromMatrix(M): #input is a hyperbolic matrix M which lies in SL_2(Z)
    tr = np.trace(M)
    if np.abs(tr) <= 2:
        raise ValueError('Matrix should have trace > 2')
    if tr < 0:
        M = -M
        tr = -tr
    length = 2*np.log(tr/2+np.sqrt((tr/2)**2-1))
    eig = np.exp(1)**(length/2)
    a = M.item(0,0)
    b = M.item(0,1)
    c = M.item(1,0)
    d = M.item(1,1)
    if c > 0:
        eigMat = (1/((c**2)*(tr**2-4))**(1/4))*np.matrix([[eig-d,1/eig-d],[c,c]])
    else: 
        eigMat = (1/((c**2)*(tr**2-4))**(1/4))*np.matrix([[-eig+d,1/eig-d],[-c,c]])
    visPt = (eig-d)/c
    newA = eigMat.item(0,0)
    newB = eigMat.item(0,1)
    newC = eigMat.item(1,0)
    newD = eigMat.item(1,1)
    z = (newA*1j+newB)/(newC*1j+newD)
    zeta = 1j/(newC*1j+newD)**2
    return (length,eig,eigMat,visPt,z,zeta)

# %%
def inFundDom(z):
    return (np.abs(z) >= 1) and (np.abs(np.real(z))<=1/2)

# %%
def fundDomRep(z,zeta):
    mat = np.matrix([[1,0],[0,1]])
    while not inFundDom(z):
        trans = np.floor(np.real(z)+1/2) #translation factor
        z = z - trans #desired z
        mat = np.matmul(np.matrix([[1,-trans],[0,1]]),mat)
        if (np.abs(z) < 1):
            zeta = zeta/z**2
            z = -1/z
            mat = np.matmul(np.matrix([[0,1],[-1,0]]),mat)
    return (z,zeta,mat)

# %%
def cfToMatrix(sequence):
    matrix = np.eye(2, dtype=np.int64)
    for x in sequence:
        matrix = np.matmul(matrix, [[x, 1], [1, 0]])
    return matrix

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Arc
def fundDomGeo(mat,res): #input hyperbolic geodesic matrix in SL_2(Z)
    geoInfo = geodesicInfoFromMatrix(mat)
    length = geoInfo[0]
    eigMat = geoInfo[2]
    z = geoInfo[4]
    zeta = geoInfo[5]
    pointlist = []
    newRep = fundDomRep(z,zeta)
    z = newRep[0]
    zeta = newRep[1]
    eigMat = np.matmul(newRep[2],eigMat)
    pointlist.append((np.real(z),np.imag(z)))
    yMax = np.imag(z)
    fig, ax = plt.subplots(figsize=(15, 15))
    for t in range(res):
        e = np.exp(1)
        eigMat = np.matmul(eigMat,np.matrix([[e**(length/(2*res)),0],[0,e**(-length/(2*res))]]))
        newA = eigMat.item(0,0)
        newB = eigMat.item(0,1)
        newC = eigMat.item(1,0)
        newD = eigMat.item(1,1)
        z = (newA*1j+newB)/(newC*1j+newD)
        if np.imag(z) > yMax:
            yMax = np.imag(z)
        zeta = 1j/(newC*1j+newD)**2
        if not inFundDom(z):
            newRep = fundDomRep(z,zeta)
            z = newRep[0]
            zeta = newRep[1]
            eigMat = np.matmul(newRep[2],eigMat)
        pointlist.append((np.real(z),np.imag(z)))
        if t%round(res/20)==0 and t>0:
            x2,y2 = pointlist[-1]
            x1,y1 = pointlist[len(pointlist)-10]
            angle = 0
            if x2==x1:
                angle = 90
            else:
                angle = 180*math.atan2(1000*(y2-y1),1000*(x2-x1))/math.pi
            plt.plot(x2,y2, marker = (3, 0, angle+35), markersize=10, linestyle='None', color = (1-t/res,0,t/res))
    plt.ylim(0,1.05*yMax)
    plt.xlim(-1,1)
    ax.scatter(*zip(*pointlist),s=0.1)
    ax.vlines([-1/2,1/2],np.sin(np.pi/3),yMax*1.05)
    ax.add_patch(Arc((0, 0), 2, 2,
                 theta1=60, theta2=120))
    plt.show()

# %%
fundDomGeo(np.matrix([[50,49],[1,1]]),100000)

# %%
for i in range(50):
    fundDomGeo(np.matrix([[i+2,i+1],[1,1]]),100000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-95fc4f2450ff> in <module>
#       1 for i in range(50):
# ----> 2     fundDomGeo(np.matrix([[i+2,i+1],[1,1]]),100000)
#
# <ipython-input-112-0f82dedd93a1> in fundDomGeo(mat, res)
#      43     plt.ylim(0,1.05*yMax)
#      44     plt.xlim(-1,1)
# ---> 45     ax.scatter(*zip(*pointlist),s=0.1)
#      46     ax.vlines([-1/2,1/2],np.sin(np.pi/3),yMax*1.05)
#      47     ax.add_patch(Arc((0, 0), 2, 2,
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4386         # np.ma.ravel yields an ndarray, not a masked array,
#    4387         # unless its argument is a masked array.
# -> 4388         x = np.ma.ravel(x)
#    4389         y = np.ma.ravel(y)
#    4390         if x.size != y.size:
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in __call__(self, a, *args, **params)
#    6678             a, args[0] = args[0], a
#    6679
# -> 6680         marr = asanyarray(a)
#    6681         method_name = self.__name__
#    6682         method = getattr(type(marr), method_name, None)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in asanyarray(a, dtype)
#    7896     if isinstance(a, MaskedArray) and (dtype is None or dtype == a.dtype):
#    7897         return a
# -> 7898     return masked_array(a, dtype=dtype, copy=False, keep_mask=True, subok=True)
#    7899
#    7900
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in __new__(cls, data, mask, dtype, copy, subok, ndmin, fill_value, keep_mask, hard_mask, shrink, order, **options)
#    2829                 try:
#    2830                     # If data is a sequence of masked array
# -> 2831                     mask = np.array([getmaskarray(m) for m in data],
#    2832                                     dtype=mdtype)
#    2833                 except ValueError:
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in <listcomp>(.0)
#    2829                 try:
#    2830                     # If data is a sequence of masked array
# -> 2831                     mask = np.array([getmaskarray(m) for m in data],
#    2832                                     dtype=mdtype)
#    2833                 except ValueError:
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in getmaskarray(arr)
#    1477     mask = getmask(arr)
#    1478     if mask is nomask:
# -> 1479         mask = make_mask_none(np.shape(arr), getattr(arr, 'dtype', None))
#    1480     return mask
#    1481
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in make_mask_none(newshape, dtype)
#    1692     """
#    1693     if dtype is None:
# -> 1694         result = np.zeros(newshape, dtype=MaskType)
#    1695     else:
#    1696         result = np.zeros(newshape, dtype=make_mask_descr(dtype))
#
# KeyboardInterrupt:
