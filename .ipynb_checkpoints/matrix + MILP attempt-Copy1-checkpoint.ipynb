# %%
import numpy as np
import sympy as sp
from sympy import ntheory
from sympy.ntheory import continued_fraction_periodic
import math

# %%
def classRepresentatives(trace): # gives quadratic forms of given trace
    bound = math.floor(trace**2-4)
    quadraticForms = []
    i = 1
    while i**2 < bound:
        if not bound % (i**2) == 0:
            i = i + 1
            continue
        D = bound//(i**2)
        if isASquare(D):
            i = i + 1
            continue
        elif D%4 == 0:
            quadraticForms+=representatives(D)
        elif D%4 == 1:
            quadraticForms+=representatives(D)
        i = i + 1
    return [Q for Q in quadraticForms if tr(Q)==np.round(trace)]

def representatives(D):
    reps = []
    seenFracs = []
    for i in range(1,math.floor(np.sqrt(D))+1):
        B = -i
        if not (B**2-D)%4==0:
            continue
        for j in range(math.ceil((np.sqrt(D)+B)/2),math.floor((np.sqrt(D)-B)/2)+1):
            A = j
            if not ((B**2-D)//4)%A==0:
                continue
            C = ((B**2-D)//4)//A
            Q = [A,B,C]
            frac = ntheory.continued_fraction_periodic(-Q[1], 2*Q[0], disc(Q))[0]
            if frac not in seenFracs and gcd(A,B,C)==1:
                seenFracs+=permutationsOf(frac)
                reps.append(Q)
            else:
                continue
    return reps

def classCFReps(trace): # gives continued fractions of a given trace
    bound = math.floor(trace**2-4)
    cfList = []
    i = 1
    while i**2 < bound:
        if not bound % (i**2) == 0:
            i = i + 1
            continue
        D = bound//(i**2)
        if isASquare(D):
            i = i + 1
            continue
        elif D%4 == 0:
            cfList+=cfReps(D)
        elif D%4 == 1:
            cfList+=cfReps(D)
        i = i + 1
    return [cf for cf in cfList if cfTrace(cf)==np.round(trace)]

def cfReps(D):
    fracReps = []
    seenFracs = []
    for i in range(1,math.floor(np.sqrt(D))+1):
        B = -i
        if not (B**2-D)%4==0:
            continue
        for j in range(math.ceil((np.sqrt(D)+B)/2),math.floor((np.sqrt(D)-B)/2)+1):
            A = j
            if not ((B**2-D)//4)%A==0:
                continue
            C = ((B**2-D)//4)//A
            Q = [A,B,C]
            frac = ntheory.continued_fraction_periodic(-Q[1], 2*Q[0], disc(Q))[0]
            if frac not in seenFracs and gcd(A,B,C)==1:
                seenFracs+=permutationsOf(frac)
                fracReps.append(frac)
            else:
                continue
    return fracReps

def classCFReps2(trace): # gives continued fractions of a given trace
    bound = math.floor(trace**2-4)
    cfList = []
    i = 1
    while i**2 < bound:
        if not bound % (i**2) == 0:
            i = i + 1
            continue
        D = bound//(i**2)
        if isASquare(D):
            i = i + 1
            continue
        elif D%4 == 0:
            cfList+=cfReps2(D)
        elif D%4 == 1:
            cfList+=cfReps2(D)
        i = i + 1
    return [cf for cf in cfList if cfTrace(cf)==np.round(trace)]

def cfReps2(D):
    fracReps = []
    for i in range(1,math.floor(np.sqrt(D))+1):
        B = -i
        if not (B**2-D)%4==0:
            continue
        for j in range(math.ceil((np.sqrt(D)+B)/2),math.floor((np.sqrt(D)-B)/2)+1):
            A = j
            if not ((B**2-D)//4)%A==0:
                continue
            C = ((B**2-D)//4)//A
            Q = [A,B,C]
            frac = ntheory.continued_fraction_periodic(-Q[1], 2*Q[0], disc(Q))[0]
            minRep = min(permutationsOf(frac))
            if minRep not in fracReps and gcd(A,B,C)==1:
                fracReps.append(minRep)
            else:
                continue
    return fracReps

def permutationsOf(a):
    perms = []
    if len(a)%2==0:
        for n in range(0,len(a),2):
            perms.append(a[n:]+a[:n])
    else:
        for n in range(0,len(a)):
            perms.append(a[n:]+a[:n])
    return perms

def disc(Q):
    return Q[1]**2-4*Q[0]*Q[2]

def areEquivalent(Q,W):
    return ntheory.continued_fraction_periodic(-Q[1], 2*Q[0], disc(Q))[0] in permutationsOf(ntheory.continued_fraction_periodic(-W[1], 2*W[0], disc(W))[0])

def equalsQuad(L,M):
    if len(L)!=len(M):
        return False
    for l in L:
        counter = 0
        for m in M:
            if areEquivalent(m,l):
                M.remove(m)
                counter+=1
        if counter !=1:
            return False
    return True

def classNum(D):
    return len(representatives(D))

def tr(Q):
    return np.trace(quadToMat(Q))

def cfTrace(cf):
    return np.trace(cfToMat(cf))

def isASquare(n):
    for i in range(2,n):
        if n==i**2:
            return True
    return False

def gcd(a,b,c):
    return np.gcd(a,np.gcd(b,c))

def matgcd(mat):
    return gcd(mat[1,0],mat[1,1]-mat[0,0],mat[0,1])

def quadToMat(Q):
    mat = np.identity(2)
    length = 0
    for x in ntheory.continued_fraction_periodic(-Q[1], 2*Q[0],disc(Q))[0]:
        mat = np.matmul(mat,[[x,1],[1,0]])
        length += 1
    if length % 2 == 1:
        mat = np.matmul(mat,mat)
    return np.array(mat).astype(int)

# %%
def contFracToLR(contFrac):
    if len(contFrac)%2==1:
        contFrac = contFrac + contFrac
    output = []
    for i in range(len(contFrac)):
        if i%2==1: #if original cont'd frac is even length, making last one R/alternating is same as this (hopefully)
            for j in range(contFrac[i]):
                output.append(1)
        else:
            for j in range(contFrac[i]):
                output.append(0)
    return output

def recover2(ls): #sends a whole list to a cont'd fraction (not clear whether this is needed)
    output = []
    i=0
    while i<len(ls):
        counter=1
        while(i<len(ls)-1 and ls[i] == ls[i+1]):
            i+=1
            counter+=1
        i+=1
        output.append(counter)
    if (len(output)%2!=0):
        output[len(output)-1]+=output[0]
        output = output[1:]
    return output

def indices(lrSeq): #positions of R's (R=1)
    return [i for i in range(len(lrSeq)) if lrSeq[i]==1]

def pairs(lrSeq): #pairs of R's on which to split
    output = []
    for i in indices(lrSeq):
        for j in indices(lrSeq):
            if i==j:
                continue
            else:
                output.append((i,j))
    return output

def split(contFrac): #splits a cont'd fraction on every possible pair of R's into 2 groups of R's and L's (in 0's and 1's)
    output = []
    converted = contFracToLR(contFrac)
    n = len(converted)
    splitPoints = pairs(converted)
    for i,j in splitPoints:
        temp = converted[i:]+converted[:i]
        temp1 = temp[1:(j-i)%n]
        temp2 = inv(temp[(j-i)%n+1:]) #inv(temp[(j-i)%n+1:])
        output.append((tuple(temp1),tuple(temp2)))
    return output

def printCon(lrSeq): #R = 1, L = 0
    a = ''
    for i in lrSeq:
        if i==1:
            a+= 'R'
        else:
            a+= 'L'
    return a

def printConLs(ls):
    printList = []
    for L in ls:
        printList.append(printCon(L))
    return printList

#def getDict(contFrac):
#    output = []
#    fracs = []
#    for t in range(1+2*e):
#        tr = trace-e+t
#        fracs += [ntheory.continued_fraction_periodic(-Q[1], 2*Q[0], disc(Q))[0] for Q in classRepresentatives(tr)]
#    for f in fracs:
#        output += split(f)
#    return output

#def cfListToDict(cfList):
#    outputDict = {}
#    for cf in cfList:
#        for obj in split(cf):
#            if obj[0] in outputDict:
#                outputDict[obj[0]].add(obj[1])
#            else:
#                outputDict[obj[0]] = {obj[1]}
#    return outputDict

def cfListToDicts(cfList):
    forwardDict = {}
    invDict = {}
    for cf in cfList:
        for obj in split(cf):
            if obj[0] in forwardDict:
                forwardDict[obj[0]].add(obj[1])
            else:
                forwardDict[obj[0]] = {obj[1]}
            if obj[1] in invDict:
                invDict[obj[1]].add(obj[0])
            else:
                invDict[obj[1]] = {obj[0]}
    return forwardDict,invDict

def inv(lrSeq): #inverts a list of 0's and 1's (R's and L's)
    return tuple((np.array(lrSeq[::-1])-1)**2)

def pairToFrac(s1,s2):
    out = list(s1)+[1]+list(inv(s2))+[1]
    return tuple(min(permutationsOf(recover2(out))))

#def getPants(cfList): #this clearly doesn't work
#    allPairs = cfListToDict(cfList)
#    output,fracs = [],[]
#    for s0,s1 in allPairs:
#        temp1,temp2 = set([tuple(a[1]) for a in allPairs if a[0]==s0]), set([tuple(a[1]) for a in allPairs if a[0]==s1])
#        s  = temp1.intersection(temp2)
#        for s2 in s:
#            s2 = list(s2)
#            output.append([s0,s1,s2])
#            fracs = [pairToFrac(s0,inv(s1)),pairToFrac(s1,inv(s2)),pairToFrac(s2,inv(s0))]
#    return fracs

def getPants(cfList):
    dictPair = cfListToDicts(cfList)
    forwardDict = dictPair[0]
    invDict = dictPair[1]
    pants = set()
    for s0 in forwardDict:
        for s1 in forwardDict[s0]:
            if s1 in forwardDict and s0 in invDict:
                for s2 in forwardDict[s1].intersection(invDict[s0]):
                    y0,y1,y2 = pairToFrac(s0,s1),pairToFrac(s1,s2),pairToFrac(s2,s0)
                    if y0==y1 or y1==y2 or y0==y2:
                        continue
                    pants.add(frozenset((y0,y1,y2)))
    return pants

def pantsInTraceRange(traceMin,traceMax):
    cfList = []
    for trace in range(traceMin,traceMax+1):
        cfList += classCFReps(trace)
    return getPants(cfList)

def pantsInTraceRangeAndWithGivenCuff(traceMin,traceMax,cuttingSequence):
    allPants = pantsInTraceRange(traceMin,traceMax)
    pantsWithCuff = []
    for pants in allPants:
        if min(permutationsOf(cuttingSequence)) in pants:
            pantsWithCuff.append(pants)
    return pantsWithCuff

def boundaryCountForOrientedCuffs(traceMin,traceMax,cuttingSequencePositive): #i sort of screwed up orientation here
                                                                                #since surface is on the left and therefore
                                                                                #we prefer counterclockwise...
    cuttingSequenceNegative = cuttingSequencePositive[::-1]
    positiveOrientationPants = pantsInTraceRangeAndWithGivenCuff(traceMin,traceMax,cuttingSequencePositive)
    negativeOrientationPants = pantsInTraceRangeAndWithGivenCuff(traceMin,traceMax,cuttingSequenceNegative)
    return (len(positiveOrientationPants) - len(negativeOrientationPants))
            

def cfToMat(cf):
    mat = np.identity(2)
    length = 0
    for x in cf:
        mat = np.matmul(mat,[[x,1],[1,0]])
        length += 1
    if length % 2 == 1:
        mat = np.matmul(mat,mat)
    return np.array(mat).astype(int)


def pantsToGeodesics(pList):
    positives = list()
    for p in pList:
        for geo in p:
            minGeo = min(permutationsOf(geo))
            invGeo = min(permutationsOf(minGeo[::-1]))
            if minGeo in positives or invGeo in positives:
                continue
            else:
                positives.append(minGeo)
    return positives
                
def geosToEyes(geos):
    eyes = list()
    for geo in geos:
        for i in range(0,len(geo),2):
            a = list(geo[i:])+list(geo[:i])
            a = a[1:]
            a[0]-=1
            a[len(a)-1]-=1
            eyes.append((geo,tuple(a)))
    return eyes

def cuspInv(cusp):
    invCusp = list(cusp[::-1])
    if len(invCusp) == 1 and invCusp[0] <= 0:
        return tuple(invCusp)
    else:
        if invCusp[0] == 0:
            invCusp = invCusp[1:]
        else:
            invCusp = [0] + invCusp
        if invCusp[-1] == 0:
            invCusp = invCusp[:-1]
        else:
            invCusp = invCusp + [0]
        return tuple(invCusp)

def eyesToCusps(eList):
    output = list()
    for e in eList:
        eye = e[1]
        invEye = cuspInv(eye)
        if eye in output or invEye in output:
            continue
        else:
            output.append(eye)
    return output
                
def pantsAndEyesToMatrix(pantList, eyeList, posGeoList, posCuspList):
    
    geoIndexDict = {}
    cuspIndexDict = {}
    
    basisList = posGeoList + posCuspList
    
    for i in range(len(basisList)):
        if i < len(posGeoList):
            geoIndexDict[posGeoList[i]] = i 
        else:
            cuspIndexDict[posCuspList[i-len(posGeoList)]] = i
        
    colList = []
    for pants in pantList:
        col = np.zeros(len(basisList))
        for geo in pants:
            if geo in geoIndexDict:
                col[geoIndexDict[geo]] = 1
            else:
                col[geoIndexDict[min(permutationsOf(geo[::-1]))]] = -1
        colList.append(col)
    
    for eye in eyeList:
        col = np.zeros(len(basisList))
        
        if eye[0] in geoIndexDict:
            col[geoIndexDict[eye[0]]] = 1
        else:
            col[geoIndexDict[min(permutationsOf(eye[0][::-1]))]] = -1
        
        if eye[1] in cuspIndexDict:
            col[cuspIndexDict[eye[1]]] = 1
        else:
            col[cuspIndexDict[cuspInv(eye[1])]] = -1
        
        colList.append(col)
    
    return np.column_stack(colList)

# %%
pantSet = pantsInTraceRange(10,30)

# %%
posGeoList = pantsToGeodesics(pantSet)

# %%
eyeList = geosToEyes(posGeoList)

# %%
posCuspList = eyesToCusps(eyeList)

# %%
pantList = list(pantSet)

# %%
mat = pantsAndEyesToMatrix(pantList,eyeList,posGeoList,posCuspList)

# %%
from pulp import *
import numpy as np

EPS = 1e-3

""" Input """
A = mat
b = np.zeros(A.shape[0])

""" MIP """
# Variables
x = np.empty(A.shape[1], dtype=object)
for i in range(A.shape[1]):
    x[i] = LpVariable("x" + str(i), lowBound=0, upBound=None, cat='Integer')

# Problem
prob = LpProblem("prob", LpMinimize)

# Objective
prob += np.sum(x)

# Constraints
for row in range(A.shape[0]):
    prob += np.dot(A[row], x) == b[row]

prob += np.sum(x) >= EPS  # forbid zero-vector

print(prob)

# Solve
status = prob.solve()
resultList = pantList+eyeList
resultStr = ""
for i in range(len(x)):
    if value(x[i]) != 0.0:
        resultStr += "+" + str(value(x[i])) + "*" + str(resultList[i])
print(resultStr)
# Out:
# prob:
# MINIMIZE
# 1*x0 + 1*x1 + 1*x10 + 1*x100 + 1*x1000 + 1*x1001 + 1*x1002 + 1*x1003 + 1*x1004 + 1*x1005 + 1*x1006 + 1*x1007 + 1*x1008 + 1*x1009 + 1*x101 + 1*x1010 + 1*x1011 + 1*x1012 + 1*x1013 + 1*x1014 + 1*x1015 + 1*x1016 + 1*x1017 + 1*x1018 + 1*x1019 + 1*x102 + 1*x1020 + 1*x1021 + 1*x1022 + 1*x1023 + 1*x1024 + 1*x1025 + 1*x1026 + 1*x1027 + 1*x1028 + 1*x1029 + 1*x103 + 1*x1030 + 1*x1031 + 1*x1032 + 1*x1033 + 1*x1034 + 1*x1035 + 1*x1036 + 1*x1037 + 1*x1038 + 1*x1039 + 1*x104 + 1*x1040 + 1*x1041 + 1*x1042 + 1*x1043 + 1*x1044 + 1*x1045 + 1*x1046 + 1*x1047 + 1*x1048 + 1*x1049 + 1*x105 + 1*x1050 + 1*x1051 + 1*x1052 + 1*x1053 + 1*x1054 + 1*x1055 + 1*x1056 + 1*x1057 + 1*x1058 + 1*x1059 + 1*x106 + 1*x1060 + 1*x1061 + 1*x1062 + 1*x1063 + 1*x1064 + 1*x1065 + 1*x1066 + 1*x1067 + 1*x1068 + 1*x1069 + 1*x107 + 1*x1070 + 1*x1071 + 1*x1072 + 1*x1073 + 1*x1074 + 1*x1075 + 1*x1076 + 1*x1077 + 1*x1078 + 1*x1079 + 1*x108 + 1*x1080 + 1*x1081 + 1*x1082 + 1*x1083 + 1*x1084 + 1*x1085 + 1*x1086 + 1*x1087 + 1*x1088 + 1*x1089 + 1*x109 + 1*x1090 + 1*x1091 + 1*x1092 + 1*x1093 + 1*x1094 + 1*x1095 + 1*x1096 + 1*x1097 + 1*x1098 + 1*x1099 + 1*x11 + 1*x110 + 1*x1100 + 1*x1101 + 1*x1102 + 1*x1103 + 1*x1104 + 1*x1105 + 1*x1106 + 1*x1107 + 1*x1108 + 1*x1109 + 1*x111 + 1*x1110 + 1*x1111 + 1*x1112 + 1*x1113 + 1*x1114 + 1*x1115 + 1*x1116 + 1*x1117 + 1*x1118 + 1*x1119 + 1*x112 + 1*x1120 + 1*x1121 + 1*x1122 + 1*x1123 + 1*x1124 + 1*x1125 + 1*x1126 + 1*x1127 + 1*x1128 + 1*x1129 + 1*x113 + 1*x1130 + 1*x1131 + 1*x1132 + 1*x1133 + 1*x1134 + 1*x1135 + 1*x1136 + 1*x1137 + 1*x1138 + 1*x1139 + 1*x114 + 1*x1140 + 1*x115 + 1*x116 + 1*x117 + 1*x118 + 1*x119 + 1*x12 + 1*x120 + 1*x121 + 1*x122 + 1*x123 + 1*x124 + 1*x125 + 1*x126 + 1*x127 + 1*x128 + 1*x129 + 1*x13 + 1*x130 + 1*x131 + 1*x132 + 1*x133 + 1*x134 + 1*x135 + 1*x136 + 1*x137 + 1*x138 + 1*x139 + 1*x14 + 1*x140 + 1*x141 + 1*x142 + 1*x143 + 1*x144 + 1*x145 + 1*x146 + 1*x147 + 1*x148 + 1*x149 + 1*x15 + 1*x150 + 1*x151 + 1*x152 + 1*x153 + 1*x154 + 1*x155 + 1*x156 + 1*x157 + 1*x158 + 1*x159 + 1*x16 + 1*x160 + 1*x161 + 1*x162 + 1*x163 + 1*x164 + 1*x165 + 1*x166 + 1*x167 + 1*x168 + 1*x169 + 1*x17 + 1*x170 + 1*x171 + 1*x172 + 1*x173 + 1*x174 + 1*x175 + 1*x176 + 1*x177 + 1*x178 + 1*x179 + 1*x18 + 1*x180 + 1*x181 + 1*x182 + 1*x183 + 1*x184 + 1*x185 + 1*x186 + 1*x187 + 1*x188 + 1*x189 + 1*x19 + 1*x190 + 1*x191 + 1*x192 + 1*x193 + 1*x194 + 1*x195 + 1*x196 + 1*x197 + 1*x198 + 1*x199 + 1*x2 + 1*x20 + 1*x200 + 1*x201 + 1*x202 + 1*x203 + 1*x204 + 1*x205 + 1*x206 + 1*x207 + 1*x208 + 1*x209 + 1*x21 + 1*x210 + 1*x211 + 1*x212 + 1*x213 + 1*x214 + 1*x215 + 1*x216 + 1*x217 + 1*x218 + 1*x219 + 1*x22 + 1*x220 + 1*x221 + 1*x222 + 1*x223 + 1*x224 + 1*x225 + 1*x226 + 1*x227 + 1*x228 + 1*x229 + 1*x23 + 1*x230 + 1*x231 + 1*x232 + 1*x233 + 1*x234 + 1*x235 + 1*x236 + 1*x237 + 1*x238 + 1*x239 + 1*x24 + 1*x240 + 1*x241 + 1*x242 + 1*x243 + 1*x244 + 1*x245 + 1*x246 + 1*x247 + 1*x248 + 1*x249 + 1*x25 + 1*x250 + 1*x251 + 1*x252 + 1*x253 + 1*x254 + 1*x255 + 1*x256 + 1*x257 + 1*x258 + 1*x259 + 1*x26 + 1*x260 + 1*x261 + 1*x262 + 1*x263 + 1*x264 + 1*x265 + 1*x266 + 1*x267 + 1*x268 + 1*x269 + 1*x27 + 1*x270 + 1*x271 + 1*x272 + 1*x273 + 1*x274 + 1*x275 + 1*x276 + 1*x277 + 1*x278 + 1*x279 + 1*x28 + 1*x280 + 1*x281 + 1*x282 + 1*x283 + 1*x284 + 1*x285 + 1*x286 + 1*x287 + 1*x288 + 1*x289 + 1*x29 + 1*x290 + 1*x291 + 1*x292 + 1*x293 + 1*x294 + 1*x295 + 1*x296 + 1*x297 + 1*x298 + 1*x299 + 1*x3 + 1*x30 + 1*x300 + 1*x301 + 1*x302 + 1*x303 + 1*x304 + 1*x305 + 1*x306 + 1*x307 + 1*x308 + 1*x309 + 1*x31 + 1*x310 + 1*x311 + 1*x312 + 1*x313 + 1*x314 + 1*x315 + 1*x316 + 1*x317 + 1*x318 + 1*x319 + 1*x32 + 1*x320 + 1*x321 + 1*x322 + 1*x323 + 1*x324 + 1*x325 + 1*x326 + 1*x327 + 1*x328 + 1*x329 + 1*x33 + 1*x330 + 1*x331 + 1*x332 + 1*x333 + 1*x334 + 1*x335 + 1*x336 + 1*x337 + 1*x338 + 1*x339 + 1*x34 + 1*x340 + 1*x341 + 1*x342 + 1*x343 + 1*x344 + 1*x345 + 1*x346 + 1*x347 + 1*x348 + 1*x349 + 1*x35 + 1*x350 + 1*x351 + 1*x352 + 1*x353 + 1*x354 + 1*x355 + 1*x356 + 1*x357 + 1*x358 + 1*x359 + 1*x36 + 1*x360 ...
# SUBJECT TO
# _C1: x0 + x1 - x1020 + x1045 + x1046 + x106 - x11 + x111 + x16 + x169 + x175
#  + x18 - x187 + x226 + x240 + x269 + x279 - x299 + x336 - x341 + x373 - x375
#  + x430 - x45 - x467 + x518 - x543 + x563 + x585 - x608 - x661 - x692 + x695
#  + x697 - x699 + x701 + x726 - x744 + x761 + x777 + x798 + x819 - x838 - x863
#  - x864 - x887 + x902 + x908 - x942 + x988 = 0
#
# _C2: x0 - x1002 - x1012 + x1047 + x1048 - x113 - x129 - x174 - x212 + x218
#  + x23 - x237 - x255 + x256 + x258 + x273 + x310 + x311 - x32 + x320 - x322
#  + x393 - x403 - x432 + x444 - x446 + x463 + x47 + x48 + x495 + x523 + x532
#  + x560 - x567 - x572 - x605 - x606 + x623 + x666 - x707 - x719 + x72 - x742
#  - x75 - x758 + x764 - x775 + x777 + x791 - x833 + x835 + x862 - x864 - x87
#  + x884 - x898 - x92 - x921 + x928 - x945 + x952 + x955 + x959 + x967 - x98
#  = 0
#
# _C3: x0 - x1005 - x1016 - x1017 - x1027 + x1049 + x115 - x117 + x126 - x13
#  + x155 + x162 + x211 - x216 + x223 + x226 - x248 - x25 + x259 + x278 - x297
#  + x31 + x333 + x338 - x344 - x349 - x363 + x369 + x370 + x422 + x451 + x488
#  + x515 + x527 - x554 + x566 + x579 + x583 - x591 + x600 + x608 + x612 - x653
#  - x672 - x674 - x725 - x730 - x750 + x767 - x781 + x782 - x816 - x839 + x854
#  - x876 + x883 - x891 + x900 - x910 + x939 - x940 - x954 + x965 - x97 - x976
#  + x990 = 0
#
# _C4: x1 - x1026 - x1043 + x1050 + x1051 + x125 - x140 - x15 - x154 - x181
#  - x188 + x203 - x24 - x242 - x259 + x267 - x285 - x290 + x318 - x325 + x343
#  + x345 + x365 - x37 - x382 - x398 + x411 + x414 - x430 - x46 - x487 + x49
#  + x541 + x55 + x553 - x584 + x591 + x595 + x610 + x617 + x644 + x646 + x65
#  + x650 - x670 - x713 + x739 + x753 - x758 + x773 + x794 - x795 - x81 - x811
#  + x817 + x831 - x834 + x842 - x858 + x871 + x898 - x907 + x913 - x924 - x93
#  + x934 - x936 - x941 - x954 - x958 - x975 + x978 + x987 + x989 + x994 = 0
#
# _C5: x1 + x100 - x1024 - x1027 + x1033 - x1039 + x1052 + x121 - x126 + x136
#  - x146 - x174 + x184 - x193 + x208 + x225 + x230 + x232 - x244 + x259 - x268
#  + x278 - x284 + x287 - x307 + x32 + x321 + x326 - x372 - x415 + x423 + x440
#  + x460 - x461 + x471 - x485 - x489 + x490 + x530 - x537 - x539 + x555 - x556
#  - x560 + x580 + x588 - x592 - x593 - x604 + x606 + x620 + x636 - x637 + x64
#  + x640 + x648 - x654 + x66 - x675 + x681 + x692 + x698 + x700 - x71 + x743
#  + x752 - x762 - x770 + x784 + x789 - x819 + x830 - x847 + x873 + x880 + x885
#  - x897 + x902 + x905 - x916 + x924 - x949 + x958 - x989 = 0
#
# _C6: x1010 - x102 + x1053 + x1054 + x136 + x164 + x2 - x205 - x214 + x235
#  - x244 - x263 - x302 + x303 + x342 + x350 - x38 - x4 - x431 + x432 + x438
#  - x440 + x450 - x49 - x494 + x552 + x559 - x576 + x578 - x592 - x603 + x616
#  - x628 - x668 - x687 + x694 + x782 - x784 - x81 + x812 - x813 - x862 - x910
#  - x916 - x925 = 0
#
# _C7: x1016 + x1020 + x1055 + x159 + x163 + x187 + x2 + x243 + x257 + x262
#  + x294 + x296 + x298 + x309 + x350 + x410 + x44 + x445 + x469 + x539 + x543
#  + x552 + x571 + x587 + x625 + x634 + x751 + x783 + x809 + x818 + x836 + x838
#  + x843 + x851 + x871 + x951 + x955 + x978 = 0
#
# _C8: - x1006 - x1019 - x1028 + x105 + x1056 + x139 + x14 - x158 + x17 - x193
#  + x195 + x2 + x208 + x221 + x227 + x237 + x258 + x295 + x302 - x315 - x317
#  + x328 - x329 + x331 + x333 + x336 + x337 + x341 - x354 + x390 - x407 - x41
#  + x415 + x421 - x439 - x44 + x480 - x484 + x49 - x492 - x494 + x497 + x5
#  + x50 - x521 + x525 - x526 + x561 - x6 + x614 - x627 + x647 + x663 - x670
#  - x691 - x702 - x714 - x726 + x755 - x78 - x794 - x804 + x820 - x853 + x907
#  - x911 - x912 + x918 - x953 + x963 + x969 + x971 - x977 + x988 + x99 - x993
#  = 0
#
# _C9: - x1040 + x1057 + x1058 + x1059 - x121 - x130 - x161 - x179 + x207 + x210
#  - x24 + x244 - x253 + x276 - x294 + x3 + x300 + x343 - x344 - x366 - x401
#  + x405 + x457 - x479 + x491 + x503 - x526 - x555 - x630 - x663 + x672 + x689
#  + x718 + x726 + x742 - x767 + x804 + x808 + x83 + x833 + x850 + x867 + x910
#  + x919 - x920 + x926 + x973 - x974 - x998 = 0
#
# _C10: x1024 + x1060 + x108 + x117 + x161 + x191 + x239 + x3 + x311 + x334
#  + x349 + x382 + x384 + x394 + x412 + x417 + x424 + x442 + x499 + x517 + x521
#  + x526 + x537 + x593 + x60 + x610 + x614 + x617 + x626 + x638 + x646 + x666
#  + x708 + x711 + x745 + x76 + x774 + x780 + x785 + x79 + x821 + x873 + x88
#  + x892 + x900 + x911 + x935 + x944 + x973 + x985 + x991 = 0
#
# _C11: - x1001 + x1028 - x103 - x1033 + x1061 + x1062 + x112 + x114 - x125
#  + x127 - x128 + x185 + x192 - x214 - x217 - x242 - x256 + x268 - x269 + x274
#  + x280 - x295 + x3 + x309 - x351 + x367 - x39 - x422 + x434 + x456 + x469
#  + x470 - x478 - x493 - x511 + x534 + x554 - x557 - x575 - x581 + x609 + x62
#  - x685 + x693 + x707 + x708 - x757 + x769 + x776 - x779 + x784 - x793 + x795
#  - x820 + x845 + x848 - x892 - x905 + x908 - x918 - x922 + x927 + x944 - x948
#  - x990 - x999 = 0
#
# _C12: - x1014 - x1025 + x1040 + x1063 + x11 + x122 - x16 - x161 + x164 - x166
#  + x183 + x195 - x196 - x205 + x240 - x257 - x260 + x28 - x281 - x288 + x310
#  - x335 - x358 - x372 - x373 + x383 + x385 + x396 + x4 + x409 - x424 + x443
#  - x475 + x516 - x546 - x578 + x600 - x623 - x642 - x665 - x668 - x688 - x698
#  + x729 + x759 - x76 - x772 + x778 + x789 + x797 + x80 - x811 - x824 + x862
#  - x863 + x88 + x890 + x905 + x947 + x986 = 0
#
# _C13: x1064 + x1065 + x176 - x188 - x207 - x209 + x217 + x226 + x227 + x234
#  + x252 - x26 - x277 - x289 - x292 - x295 - x342 + x346 - x375 - x378 + x384
#  + x394 + x396 + x4 - x405 - x423 + x426 + x455 - x462 - x464 + x493 - x501
#  - x51 + x533 + x550 - x564 + x570 - x573 - x58 + x582 + x584 + x59 + x615
#  + x618 - x65 - x680 - x685 + x688 - x69 - x690 + x695 - x713 + x751 + x762
#  + x766 + x800 - x805 - x815 - x847 - x861 + x879 + x909 - x924 + x937 + x956
#  = 0
#
# _C14: - x1006 + x1014 + x1066 - x107 + x11 - x142 - x204 - x213 - x250 - x254
#  + x276 + x284 + x326 + x342 - x352 + x360 - x367 + x387 + x432 + x441 - x468
#  + x5 - x519 + x558 - x59 - x613 - x635 - x656 + x664 + x671 + x679 + x727
#  - x750 + x760 + x782 - x791 - x913 - x964 = 0
#
# _C15: x1003 + x1005 + x1008 + x101 - x1031 + x1067 + x109 - x122 - x138 + x151
#  - x201 - x225 - x255 - x281 + x282 + x283 + x318 + x360 - x41 - x42 - x436
#  + x449 + x453 - x456 - x458 + x5 - x53 + x533 + x571 - x58 - x596 + x6 - x611
#  - x612 - x621 - x644 + x649 - x680 - x723 - x752 + x769 - x802 - x804 - x82
#  - x824 + x830 - x845 + x851 - x856 - x857 + x889 - x898 - x915 - x940 + x951
#  - x96 + x967 + x979 - x993 = 0
#
# _C16: x10 + x1003 + x1010 + x1018 + x1068 + x109 + x120 + x160 + x168 + x273
#  + x274 + x280 + x359 + x365 + x366 + x397 + x461 + x541 + x559 + x570 + x589
#  + x597 + x6 + x616 + x730 + x812 + x849 + x863 + x95 + x972 + x979 + x992
#  + x995 = 0
#
# _C17: x1018 + x1021 + x1024 + x1025 + x1041 + x1042 + x1069 + x1070 + x129
#  + x150 + x155 + x159 + x173 + x197 + x251 + x275 + x279 + x308 + x315 + x328
#  + x348 + x349 + x36 + x385 + x421 + x425 + x464 + x487 + x499 + x527 + x557
#  + x57 + x571 + x580 + x601 + x613 + x641 + x668 + x678 + x7 + x701 + x704
#  + x740 + x747 + x860 + x906 + x947 + x981 = 0
#
# _C18: - x1000 - x1026 + x1040 + x1042 + x1071 + x1072 + x148 - x183 + x218
#  + x228 - x262 + x265 + x267 + x287 + x29 + x335 + x388 - x404 - x413 - x435
#  + x459 - x477 + x562 + x575 - x579 + x584 + x627 + x641 + x65 + x663 + x673
#  + x7 + x736 + x74 + x75 + x858 - x90 + x943 + x977 - x983 = 0
#
# _C19: x1013 + x1031 + x104 + x1073 + x123 + x142 + x149 + x180 + x182 + x20
#  + x220 + x266 + x272 + x33 + x351 + x39 + x399 + x434 + x458 + x494 + x537
#  + x544 + x577 + x61 + x646 + x658 + x67 + x673 + x689 + x7 + x728 + x768
#  + x821 + x827 + x83 + x851 + x941 + x972 + x974 = 0
#
# _C20: x100 + x1007 + x1022 + x1074 + x1075 + x117 + x119 + x139 + x144 + x156
#  + x162 + x163 + x165 + x166 + x170 + x205 + x271 + x314 + x369 + x383 + x388
#  + x484 + x518 + x535 + x551 + x562 + x593 + x597 + x60 + x652 + x656 + x673
#  + x697 + x70 + x717 + x775 + x778 + x8 + x815 + x822 + x865 + x895 + x946
#  + x951 + x962 + x969 + x975 + x999 = 0
#
# _C21: x1023 - x1034 + x1076 + x1077 + x110 - x132 + x149 + x150 + x210 + x221
#  + x253 - x255 + x263 - x265 + x267 - x27 + x362 - x391 + x407 + x423 - x430
#  - x442 + x450 + x476 - x497 - x502 + x504 + x507 + x508 + x517 + x534 + x540
#  - x546 + x569 - x585 + x590 + x606 + x607 - x612 - x63 - x632 + x636 - x638
#  - x680 - x703 + x713 - x729 - x73 - x731 + x736 + x741 + x748 + x8 + x819
#  - x858 + x878 - x894 - x91 + x918 - x935 + x938 + x940 + x942 + x945 + x950
#  + x958 - x960 - x970 - x991 = 0
#
# _C22: x1078 + x1079 + x112 + x128 + x129 + x137 + x141 + x150 - x214 + x233
#  - x313 + x314 + x347 + x356 + x369 - x379 - x381 - x382 - x386 + x390 + x413
#  + x455 - x459 + x47 + x487 + x491 - x510 + x527 + x540 - x542 + x565 + x590
#  - x596 - x619 - x626 - x628 + x630 + x633 + x686 + x715 + x735 - x761 + x8
#  - x80 + x808 + x815 + x817 + x850 + x856 + x870 + x888 - x900 - x933 + x948
#  - x980 = 0
#
# _C23: x1003 - x102 + x1038 + x1080 + x1081 - x134 - x16 - x17 - x177 - x186
#  - x19 + x213 + x222 + x240 - x242 - x266 - x277 - x30 - x322 - x325 + x35
#  + x356 - x360 - x361 + x37 + x380 - x416 + x424 - x448 + x451 + x478 - x485
#  - x522 + x538 - x553 - x620 + x631 - x639 - x662 - x677 - x721 - x748 + x754
#  + x756 + x770 + x771 + x813 + x834 + x836 + x837 - x850 + x854 + x877 + x893
#  + x9 + x901 - x944 - x977 - x985 = 0
#
# _C24: - x103 + x1082 + x160 - x191 - x201 + x241 + x284 - x304 - x327 - x345
#  - x381 - x39 + x393 - x395 + x420 - x439 - x502 - x520 + x551 + x64 - x642
#  - x658 - x659 + x676 - x683 + x694 + x710 + x720 - x737 + x744 - x831 + x843
#  + x882 + x899 + x9 + x91 + x920 + x956 - x970 + x981 = 0
#
# _C25: x1022 + x1026 + x1027 + x1028 + x1083 + x123 + x131 + x173 + x216 + x234
#  + x260 + x313 + x324 + x364 + x400 + x420 + x443 + x473 + x479 + x531 + x560
#  + x561 + x579 + x591 + x594 + x601 + x604 + x660 + x682 + x692 + x714 + x73
#  + x762 + x78 + x810 + x822 + x835 + x872 + x893 + x9 + x90 + x914 + x920
#  + x942 + x989 = 0
#
# _C26: x10 + x1001 - x1013 - x1033 - x108 + x1084 + x1085 + x109 + x12 + x13
#  - x132 - x156 - x171 - x178 + x202 + x220 - x228 - x238 + x243 - x25 - x286
#  - x331 - x350 + x362 + x371 + x38 - x389 + x398 + x400 - x41 + x410 + x419
#  + x427 + x498 - x508 + x528 + x530 + x531 - x54 - x549 - x558 - x567 + x586
#  - x592 + x602 + x633 + x635 + x643 + x648 - x657 - x66 - x676 - x678 - x682
#  + x686 - x690 - x708 + x71 - x721 + x732 - x773 + x786 + x788 - x799 - x808
#  - x824 + x828 + x844 + x861 - x87 + x875 - x887 - x888 + x911 + x92 - x939
#  + x988 - x996 = 0
#
# _C27: x10 - x1017 + x1029 + x1039 + x1044 + x1086 - x126 - x140 + x152 - x153
#  - x157 + x159 + x163 - x167 - x174 + x250 - x27 - x270 + x276 + x282 - x327
#  + x339 + x340 + x355 + x366 - x368 - x386 + x392 + x40 + x505 - x545 + x558
#  - x568 - x574 - x581 + x595 + x664 + x68 - x720 + x765 + x806 - x847 - x866
#  - x874 + x881 + x927 + x938 - x954 + x995 = 0
#
# _C28: x1035 + x1087 + x119 + x12 + x133 + x151 + x222 + x235 + x283 + x330
#  + x348 + x40 + x650 + x691 + x744 + x765 + x769 + x816 + x827 + x879 + x884
#  + x927 + x968 + x997 = 0
#
# _C29: - x1000 - x1030 - x1037 + x1088 + x12 + x152 - x212 + x222 - x30 - x300
#  - x321 + x36 - x391 + x399 + x406 - x413 - x433 - x452 + x474 - x500 - x504
#  - x520 - x556 - x566 + x589 + x618 - x619 + x652 + x669 - x676 + x691 + x709
#  - x725 + x776 - x781 - x799 - x805 + x823 + x842 + x880 - x890 + x891 - x897
#  - x899 + x928 - x971 + x997 = 0
#
# _C30: x1038 + x1043 + x1089 + x114 + x13 + x178 + x179 + x193 + x20 + x236
#  + x251 + x264 + x305 + x31 + x316 + x317 + x344 + x404 + x434 + x435 + x489
#  + x50 + x513 + x52 + x535 + x546 + x551 + x61 + x62 + x623 + x629 + x645
#  + x653 + x681 + x688 + x705 + x71 + x712 + x747 + x770 + x794 + x80 + x840
#  + x931 + x94 + x946 + x950 + x981 = 0
#
# _C31: - x1009 - x1011 + x104 + x1041 + x1090 - x120 - x131 + x14 - x151 - x157
#  - x172 + x176 - x206 - x215 + x233 + x249 - x251 - x254 + x28 + x293 - x296
#  - x298 - x300 + x304 + x306 + x379 - x429 + x433 + x437 - x469 + x477 - x479
#  + x48 - x482 - x500 + x528 - x531 + x548 + x600 + x633 - x654 - x669 + x703
#  + x711 + x723 - x745 - x753 + x757 + x764 - x799 - x852 + x874 - x878 + x907
#  + x937 - x946 + x999 = 0
#
# _C32: - x1008 + x1017 - x1035 - x107 + x1091 + x1092 + x14 - x172 - x177
#  + x186 + x188 - x216 + x218 - x239 - x245 + x265 + x278 - x301 - x302 + x312
#  + x314 - x317 + x32 + x329 - x339 + x35 + x357 - x395 - x397 - x417 + x425
#  - x465 - x472 - x474 - x486 - x503 + x549 - x58 + x585 + x599 - x604 + x626
#  + x636 + x645 + x657 - x659 + x665 + x667 + x67 + x677 - x706 + x716 - x733
#  - x736 - x75 + x758 - x763 + x787 + x807 - x809 - x818 - x82 - x821 - x832
#  + x866 - x870 + x877 + x90 - x902 - x903 + x925 + x945 - x95 + x966 + x998
#  = 0
#
# _C33: x1023 + x1025 + x1093 + x132 + x146 + x15 + x166 + x177 + x200 + x220
#  + x227 + x246 + x258 + x261 + x301 + x310 + x312 + x315 + x323 + x33 + x34
#  + x343 + x363 + x370 + x381 + x396 + x401 + x427 + x476 + x481 + x484 + x497
#  + x503 + x514 + x534 + x542 + x553 + x598 + x602 + x700 + x722 + x771 + x773
#  + x841 + x844 + x855 + x894 + x933 + x961 + x974 = 0
#
# _C34: x1036 - x1037 + x106 + x1094 + x1095 + x116 - x124 + x143 + x147 + x148
#  + x15 - x167 - x18 - x182 - x198 + x201 - x210 - x231 + x269 - x277 + x312
#  - x322 + x327 + x347 - x351 + x370 - x405 - x438 - x456 - x486 - x498 - x506
#  - x507 - x508 - x51 - x512 - x549 + x575 - x607 - x611 + x684 + x696 - x699
#  - x70 - x704 - x706 + x723 - x724 - x731 - x739 - x779 - x786 + x825 - x833
#  + x840 + x841 - x860 - x865 + x88 - x885 - x908 - x915 - x921 - x936 - x949
#  - x987 = 0
#
# _C35: x100 + x1002 + x1096 + x1097 - x124 + x155 - x160 + x162 + x17 - x178
#  + x180 - x194 + x211 - x212 + x224 + x245 + x249 - x288 + x323 - x324 + x353
#  + x378 + x411 + x439 + x446 - x454 + x455 + x47 - x473 + x498 - x50 + x506
#  + x511 - x517 + x522 + x528 + x532 + x536 + x538 - x566 + x569 - x574 - x576
#  + x580 + x603 - x660 + x684 + x69 + x721 - x759 + x761 - x783 + x800 - x805
#  + x848 - x873 - x914 - x931 + x99 = 0
#
# _C36: x1023 - x1041 - x106 + x1098 + x1099 + x118 - x141 - x148 + x18 - x182
#  - x186 + x20 - x221 + x224 - x229 - x230 - x237 + x264 + x283 + x297 + x298
#  + x307 - x346 - x353 - x368 - x377 + x40 + x436 + x440 + x462 - x548 - x567
#  + x611 - x622 - x628 + x629 + x634 - x647 - x658 + x667 - x686 + x714 - x717
#  - x724 + x735 - x737 - x763 + x77 - x774 - x789 + x79 + x823 + x84 + x849
#  + x85 + x869 - x883 - x901 + x930 - x939 - x952 - x959 + x964 + x973 + x985
#  + x992 = 0
#
# _C37: x1100 + x1101 + x121 - x138 + x139 + x143 + x165 + x176 + x19 - x191
#  + x24 + x253 + x271 + x320 - x323 + x35 + x37 + x421 + x451 - x466 + x48
#  + x493 + x502 + x509 - x513 - x520 - x53 + x54 + x545 - x568 + x57 + x582
#  + x583 - x621 + x640 + x648 + x678 - x711 - x722 + x738 - x774 + x796 - x798
#  + x846 - x855 - x892 - x943 + x952 + x980 + x984 + x998 = 0
#
# _C38: x101 - x1010 + x1015 + x1032 - x105 + x1102 + x1103 + x111 + x175 + x19
#  + x211 - x219 + x229 - x231 + x239 + x246 + x264 + x286 - x316 - x377 - x378
#  - x42 - x442 - x446 - x452 - x460 - x473 - x475 - x481 - x509 + x563 + x569
#  + x617 + x62 + x671 - x793 + x797 - x838 + x844 + x867 - x882 + x897 + x922
#  + x929 + x932 = 0
#
# _C39: x1007 + x1015 + x104 - x108 + x1104 + x1105 - x113 + x157 + x158 - x169
#  + x207 - x209 + x21 - x22 + x229 + x231 - x236 + x26 - x260 - x316 + x325
#  - x334 + x356 - x402 + x412 + x435 + x436 + x465 - x476 - x515 + x523 + x536
#  + x550 + x576 - x614 + x620 + x677 - x700 - x705 - x74 + x740 + x742 + x743
#  + x748 - x81 - x843 + x845 + x860 + x865 + x87 - x874 + x875 - x890 - x915
#  + x922 - x925 + x933 + x934 - x94 - x96 + x960 + x976 - x982 = 0
#
# _C40: x1000 - x1014 - x1016 + x1034 + x1106 + x116 - x120 - x123 - x134 + x149
#  + x195 + x198 - x199 + x21 + x232 - x274 + x292 + x293 - x319 - x321 + x331
#  + x337 - x355 + x403 - x418 + x425 + x43 + x459 + x46 + x460 + x464 + x478
#  + x488 - x492 + x512 - x52 + x524 - x529 + x532 + x574 + x596 + x599 - x601
#  + x642 - x751 - x754 + x775 + x786 - x788 + x800 - x809 - x822 + x825 + x829
#  - x849 + x855 + x875 + x901 - x932 - x955 - x963 + x965 - x968 + x975 - x978
#  + x982 = 0
#
# _C41: x1004 - x1032 + x1107 + x1108 + x128 + x131 - x137 - x165 - x184 + x198
#  + x199 + x200 + x21 - x230 + x233 + x246 - x247 + x249 - x26 - x272 - x275
#  - x281 - x285 + x289 + x29 - x301 + x33 - x334 + x336 - x337 + x408 - x422
#  + x431 - x45 + x468 + x471 + x483 + x489 - x491 - x500 + x506 + x521 - x522
#  - x552 - x56 - x572 + x587 + x594 + x598 - x607 + x622 + x625 + x640 + x653
#  + x655 - x664 - x685 + x719 + x741 + x787 - x79 + x790 - x810 - x846 + x859
#  + x86 - x868 - x876 - x894 - x899 - x916 - x917 - x931 - x936 + x979 - x993
#  + x995 + x997 = 0
#
# _C42: x102 + x1038 + x1109 + x140 + x168 + x171 + x179 - x180 + x22 + x234
#  + x235 - x27 - x28 + x305 + x332 - x371 + x418 + x452 - x483 - x496 + x499
#  - x513 - x524 + x56 + x60 - x619 - x647 + x661 + x675 + x679 + x687 - x695
#  - x696 + x73 + x752 - x777 + x783 - x820 - x828 + x835 - x841 - x86 + x866
#  - x896 - x923 - x983 - x984 = 0
#
# _C43: x1021 + x1029 + x1110 + x130 + x135 + x136 + x144 + x170 + x172 + x183
#  + x199 + x202 + x219 + x22 + x268 + x288 + x291 + x297 + x307 + x308 + x341
#  + x393 + x447 + x45 + x450 + x492 + x554 + x577 + x654 + x72 + x753 + x754
#  + x766 + x788 + x790 + x832 + x839 + x886 + x887 + x889 + x91 + x956 + x994
#  = 0
#
# _C44: - x1012 - x1030 + x1032 - x1037 + x1111 + x1112 - x115 - x168 - x219
#  + x23 - x241 + x252 - x257 + x286 + x290 - x291 + x328 + x357 + x361 + x383
#  + x385 + x416 - x447 + x471 + x483 - x516 + x530 - x561 - x573 + x639 + x659
#  - x681 - x682 + x684 + x689 + x706 - x727 + x734 + x764 + x797 + x798 - x810
#  + x828 + x831 + x854 - x886 + x937 - x950 + x960 + x969 + x987 = 0
#
# _C45: x1007 + x1015 + x1030 + x1113 - x153 - x167 + x181 + x184 - x189 + x194
#  + x208 + x23 + x252 - x263 + x285 - x296 + x299 - x30 + x303 + x306 - x309
#  + x320 + x332 + x333 + x358 - x359 + x377 - x400 + x404 - x428 + x43 + x501
#  - x535 + x538 + x542 + x557 + x572 + x582 - x588 - x594 - x61 + x63 + x630
#  + x632 - x634 + x637 + x657 + x66 - x679 + x690 + x70 + x704 - x710 + x715
#  + x716 + x717 - x72 + x720 + x74 + x740 - x747 - x765 - x766 - x772 - x78
#  - x780 + x785 + x793 - x832 - x839 - x893 - x929 + x96 - x971 + x98 - x994
#  = 0
#
# _C46: - x1004 - x1009 - x1018 - x1035 + x1114 + x113 + x124 + x171 + x194
#  + x209 + x25 - x326 + x379 - x392 + x415 - x419 - x445 - x448 + x462 + x466
#  - x470 + x475 + x485 + x515 + x56 + x565 + x588 - x597 + x64 - x650 + x667
#  + x672 + x696 - x702 + x707 + x729 + x749 - x755 - x756 + x795 - x816 + x829
#  + x853 - x869 + x876 + x878 - x879 - x884 - x89 - x904 + x912 - x972 = 0
#
# _C47: x1043 + x1115 + x1116 - x116 + x135 - x156 - x256 - x266 + x270 - x275
#  + x31 - x345 - x346 - x362 - x371 - x374 - x395 + x412 + x433 + x443 - x457
#  - x523 - x53 - x544 + x545 - x550 - x555 + x565 + x603 - x632 + x645 - x719
#  - x741 - x767 - x778 + x785 - x807 - x814 + x829 - x834 - x86 - x861 - x867
#  - x877 + x896 - x926 - x93 - x947 - x957 = 0
#
# _C48: - x1029 + x1117 + x1118 + x122 - x137 + x141 - x146 - x181 + x261 - x271
#  + x290 + x293 + x305 - x330 - x335 + x338 + x34 + x353 + x357 - x363 - x364
#  - x373 - x374 - x390 + x420 + x43 + x437 - x445 + x481 + x496 - x501 - x507
#  - x509 - x51 + x511 + x512 + x514 - x519 - x52 + x536 - x544 - x547 + x564
#  - x57 + x583 - x589 + x605 - x624 - x627 + x683 - x687 - x712 + x715 - x716
#  - x734 - x738 - x743 - x745 + x749 + x76 - x780 - x796 + x807 - x814 - x872
#  - x883 - x885 - x888 - x889 - x921 + x923 + x93 + x948 - x957 + x961 - x98
#  + x984 - x99 - x990 = 0
#
# _C49: x1020 + x1119 + x1120 + x175 + x200 + x236 + x324 + x34 + x340 + x403
#  + x416 + x417 + x441 + x457 + x458 + x46 + x482 + x540 + x559 + x629 + x641
#  + x69 + x725 + x757 + x779 + x796 + x802 + x803 + x846 + x853 + x886 + x957
#  + x965 + x986 + x991 = 0
#
# _C50: x1004 + x1005 + x1008 + x1039 + x1121 + x189 + x192 + x206 + x241 + x318
#  + x319 + x339 + x36 + x399 + x419 + x533 + x547 + x578 + x595 + x652 + x661
#  + x693 + x702 + x756 + x77 + x930 + x967 = 0
#
# _C51: x103 + x1122 + x154 + x187 + x232 + x238 + x261 + x306 + x38 + x394
#  + x401 + x42 + x428 + x431 + x447 + x518 + x524 + x529 + x556 + x638 + x639
#  + x649 + x660 + x666 + x701 + x734 + x737 + x760 + x771 + x812 + x814 + x868
#  + x94 + x966 = 0
#
# _C52: - x1013 - x105 + x1123 + x133 + x144 - x147 + x192 + x196 + x206 - x217
#  - x238 - x270 - x272 + x273 - x289 + x308 - x338 - x347 + x364 + x365 - x398
#  - x407 - x409 + x410 + x44 - x465 - x480 - x486 + x490 - x510 + x525 - x564
#  + x570 + x577 + x587 - x605 - x621 - x63 + x662 + x671 - x698 + x730 - x731
#  - x739 + x760 - x787 + x801 - x825 - x83 + x836 - x868 + x881 - x92 - x923
#  + x930 - x934 - x943 + x95 - x959 - x970 - x986 = 0
#
# _C53: x1002 + x1031 + x111 + x1124 + x1125 + x114 + x291 + x292 + x361 + x374
#  + x387 + x388 + x409 + x427 + x429 + x488 + x514 + x54 + x543 + x548 + x590
#  + x599 + x610 + x616 + x705 + x724 + x738 + x746 + x781 + x806 + x857 + x912
#  + x914 + x926 + x935 = 0
#
# _C54: x1126 + x142 + x380 + x408 + x444 + x453 + x55 + x586 + x613 + x624
#  + x656 + x669 + x733 + x776 + x823 + x881 + x89 + x909 + x953 + x97 = 0
#
# _C55: - x1012 - x110 + x1127 - x115 + x118 + x119 - x134 + x145 - x299 + x348
#  + x354 - x372 - x389 - x402 - x428 - x429 + x444 - x477 - x482 - x490 + x505
#  + x547 + x55 - x573 + x609 + x643 + x651 - x699 - x718 + x733 - x759 + x827
#  + x837 + x852 + x859 - x882 - x896 + x909 - x917 - x929 - x963 + x97 = 0
#
# _C56: x1019 + x107 + x1128 + x185 + x215 + x392 + x406 + x59 + x631 + x651
#  + x655 + x732 + x750 + x791 + x85 + x913 = 0
#
# _C57: x1001 - x1022 + x1034 + x1036 + x1129 - x130 - x133 + x143 + x147 + x154
#  + x158 - x173 - x202 + x223 + x245 - x280 - x319 - x352 + x358 - x359 - x376
#  + x386 - x389 + x411 + x437 - x449 + x466 - x504 - x539 + x622 - x651 + x67
#  + x683 - x709 - x712 - x718 + x722 - x746 - x790 - x792 - x803 + x817 - x818
#  + x870 - x871 - x89 - x917 + x941 + x966 - x992 = 0
#
# _C58: - x101 + x1011 + x1019 + x1130 + x127 - x164 + x190 - x196 + x197 + x248
#  - x340 + x376 + x414 - x418 - x448 + x463 - x467 + x472 + x615 + x624 + x631
#  - x649 + x655 + x68 - x710 + x732 - x755 + x768 - x806 + x84 - x880 + x895
#  = 0
#
# _C59: x1131 + x68 = 0
#
# _C60: x1021 - x1036 + x110 - x112 + x1132 - x125 - x138 + x145 + x170 + x189
#  + x190 + x204 - x224 + x243 + x247 + x294 - x329 - x332 + x387 + x397 + x406
#  + x441 + x453 + x461 - x496 - x510 + x541 - x568 + x625 - x637 - x665 - x670
#  + x693 - x703 - x735 - x763 + x77 + x801 - x811 + x826 - x848 + x872 + x904
#  + x919 - x949 + x968 - x976 - x980 - x982 + x996 = 0
#
# _C61: x1011 + x1133 + x127 + x352 + x505 + x826 + x84 = 0
#
# _C62: x1044 + x1134 + x185 + x203 + x215 - x247 - x303 + x330 - x375 + x380
#  + x408 + x426 - x438 - x454 + x495 - x516 - x525 - x529 + x586 - x608 - x662
#  + x674 - x675 + x728 - x746 - x772 + x792 - x803 + x826 - x830 + x85 - x864
#  + x903 + x906 - x919 - x932 - x938 + x953 + x962 - x983 - x996 = 0
#
# _C63: x1006 + x1135 + x118 + x197 + x203 + x213 + x282 + x426 + x468 + x495
#  + x609 + x635 + x674 + x709 + x768 + x852 + x895 + x903 + x904 = 0
#
# _C64: x1042 + x1136 + x135 + x223 + x262 + x279 + x304 + x311 + x313 + x384
#  + x391 + x402 + x454 + x467 + x480 + x562 + x563 + x598 + x602 + x697 + x727
#  + x749 + x802 + x813 + x840 + x857 + x961 = 0
#
# _C65: x1137 + x145 + x152 + x248 + x254 + x367 + x414 + x463 + x472 + x615
#  + x792 + x964 = 0
#
# _C66: x1138 + x190 + x250 = 0
#
# _C67: x1044 + x1139 + x204 + x376 = 0
#
# _C68: x1009 + x1140 + x354 + x355 + x449 + x470 + x474 + x519 + x618 + x643
#  + x694 + x728 + x801 + x837 + x842 + x859 + x869 + x891 + x906 + x928 + x962
#  = 0
#
# _C69: x1045 = 0
#
# _C70: x1046 = 0
#
# _C71: x1047 - x1104 + x1107 = 0
#
# _C72: x1048 + x1074 - x1077 + x1081 - x1120 = 0
#
# _C73: x1049 + x1063 - x1094 + x1113 + x1136 = 0
#
# _C74: x1050 - x1097 = 0
#
# _C75: x1051 + x1062 + x1075 + x1085 = 0
#
# _C76: x1052 + x1056 + x1082 - x1095 + x1109 - x1116 - x1117 + x1122 = 0
#
# _C77: x1053 - x1089 = 0
#
# _C78: x1054 - x1073 - x1086 + x1118 - x1132 = 0
#
# _C79: x1055 + x1066 = 0
#
# _C80: x1057 = 0
#
# _C81: x1058 = 0
#
# _C82: x1059 = 0
#
# _C83: x1060 + x1114 = 0
#
# _C84: x1061 - x1112 = 0
#
# _C85: x1064 + x1084 - x1092 - x1105 = 0
#
# _C86: x1065 + x1069 - x1076 + x1080 - x1125 = 0
#
# _C87: x1067 + x1088 + x1123 + x1127 + x1130 + x1134 = 0
#
# _C88: x1068 = 0
#
# _C89: x1070 + x1099 + x1108 = 0
#
# _C90: x1071 = 0
#
# _C91: x1072 = 0
#
# _C92: x1078 = 0
#
# _C93: x1079 = 0
#
# _C94: x1083 = 0
#
# _C95: x1087 = 0
#
# _C96: x1090 + x1106 = 0
#
# _C97: x1091 - x1119 = 0
#
# _C98: x1093 = 0
#
# _C99: x1096 = 0
#
# _C100: x1098 - x1111 = 0
#
# _C101: x1100 = 0
#
# _C102: x1101 = 0
#
# _C103: x1102 = 0
#
# _C104: x1103 = 0
#
# _C105: x1110 = 0
#
# _C106: x1115 - x1129 = 0
#
# _C107: x1121 = 0
#
# _C108: x1124 = 0
#
# _C109: x1126 = 0
#
# _C110: x1128 = 0
#
# _C111: x1131 = 0
#
# _C112: x1133 = 0
#
# _C113: x1135 = 0
#
# _C114: x1137 = 0
#
# _C115: x1138 = 0
#
# _C116: x1139 = 0
#
# _C117: x1140 = 0
#
# _C118: x0 + x1 + x10 + x100 + x1000 + x1001 + x1002 + x1003 + x1004 + x1005
#  + x1006 + x1007 + x1008 + x1009 + x101 + x1010 + x1011 + x1012 + x1013
#  + x1014 + x1015 + x1016 + x1017 + x1018 + x1019 + x102 + x1020 + x1021
#  + x1022 + x1023 + x1024 + x1025 + x1026 + x1027 + x1028 + x1029 + x103
#  + x1030 + x1031 + x1032 + x1033 + x1034 + x1035 + x1036 + x1037 + x1038
#  + x1039 + x104 + x1040 + x1041 + x1042 + x1043 + x1044 + x1045 + x1046
#  + x1047 + x1048 + x1049 + x105 + x1050 + x1051 + x1052 + x1053 + x1054
#  + x1055 + x1056 + x1057 + x1058 + x1059 + x106 + x1060 + x1061 + x1062
#  + x1063 + x1064 + x1065 + x1066 + x1067 + x1068 + x1069 + x107 + x1070
#  + x1071 + x1072 + x1073 + x1074 + x1075 + x1076 + x1077 + x1078 + x1079
#  + x108 + x1080 + x1081 + x1082 + x1083 + x1084 + x1085 + x1086 + x1087
#  + x1088 + x1089 + x109 + x1090 + x1091 + x1092 + x1093 + x1094 + x1095
#  + x1096 + x1097 + x1098 + x1099 + x11 + x110 + x1100 + x1101 + x1102 + x1103
#  + x1104 + x1105 + x1106 + x1107 + x1108 + x1109 + x111 + x1110 + x1111
#  + x1112 + x1113 + x1114 + x1115 + x1116 + x1117 + x1118 + x1119 + x112
#  + x1120 + x1121 + x1122 + x1123 + x1124 + x1125 + x1126 + x1127 + x1128
#  + x1129 + x113 + x1130 + x1131 + x1132 + x1133 + x1134 + x1135 + x1136
#  + x1137 + x1138 + x1139 + x114 + x1140 + x115 + x116 + x117 + x118 + x119
#  + x12 + x120 + x121 + x122 + x123 + x124 + x125 + x126 + x127 + x128 + x129
#  + x13 + x130 + x131 + x132 + x133 + x134 + x135 + x136 + x137 + x138 + x139
#  + x14 + x140 + x141 + x142 + x143 + x144 + x145 + x146 + x147 + x148 + x149
#  + x15 + x150 + x151 + x152 + x153 + x154 + x155 + x156 + x157 + x158 + x159
#  + x16 + x160 + x161 + x162 + x163 + x164 + x165 + x166 + x167 + x168 + x169
#  + x17 + x170 + x171 + x172 + x173 + x174 + x175 + x176 + x177 + x178 + x179
#  + x18 + x180 + x181 + x182 + x183 + x184 + x185 + x186 + x187 + x188 + x189
#  + x19 + x190 + x191 + x192 + x193 + x194 + x195 + x196 + x197 + x198 + x199
#  + x2 + x20 + x200 + x201 + x202 + x203 + x204 + x205 + x206 + x207 + x208
#  + x209 + x21 + x210 + x211 + x212 + x213 + x214 + x215 + x216 + x217 + x218
#  + x219 + x22 + x220 + x221 + x222 + x223 + x224 + x225 + x226 + x227 + x228
#  + x229 + x23 + x230 + x231 + x232 + x233 + x234 + x235 + x236 + x237 + x238
#  + x239 + x24 + x240 + x241 + x242 + x243 + x244 + x245 + x246 + x247 + x248
#  + x249 + x25 + x250 + x251 + x252 + x253 + x254 + x255 + x256 + x257 + x258
#  + x259 + x26 + x260 + x261 + x262 + x263 + x264 + x265 + x266 + x267 + x268
#  + x269 + x27 + x270 + x271 + x272 + x273 + x274 + x275 + x276 + x277 + x278
#  + x279 + x28 + x280 + x281 + x282 + x283 + x284 + x285 + x286 + x287 + x288
#  + x289 + x29 + x290 + x291 + x292 + x293 + x294 + x295 + x296 + x297 + x298
#  + x299 + x3 + x30 + x300 + x301 + x302 + x303 + x304 + x305 + x306 + x307
#  + x308 + x309 + x31 + x310 + x311 + x312 + x313 + x314 + x315 + x316 + x317
#  + x318 + x319 + x32 + x320 + x321 + x322 + x323 + x324 + x325 + x326 + x327
#  + x328 + x329 + x33 + x330 + x331 + x332 + x333 + x334 + x335 + x336 + x337
#  + x338 + x339 + x34 + x340 + x341 + x342 + x343 + x344 + x345 + x346 + x347
#  + x348 + x349 + x35 + x350 + x351 + x352 + x353 + x354 + x355 + x356 + x357
#  + x358 + x359 + x36 + x360 + x361 + x362 + x363 + x364 + x365 + x366 + x367
#  + x368 + x369 + x37 + x370 + x371 + x372 + x373 + x374 + x375 + x376 + x377
#  + x378 + x379 + x38 + x380 + x381 + x382 + x383 + x384 + x385 + x386 + x387
#  + x388 + x389 + x39 + x390 + x391 + x392 + x393 + x394 + x395 + x396 + x397
#  + x398 + x399 + x4 + x40 + x400 + x401 + x402 + x403 + x404 + x405 + x406
#  + x407 + x408 + x409 + x41 + x410 + x411 + x412 + x413 + x414 + x415 + x416
#  + x417 + x418 + x419 + x42 + x420 + x421 + x422 + x423 + x424 + x425 + x426
#  + x427 + x428 + x429 + x43 + x430 + x431 + x432 + x433 + x434 + x435 + x436
#  + x437 + x438 + x439 + x44 + x440 + x441 + x442 + x443 + x444 + x445 + x446
#  + x447 + x448 + x449 + x45 + x450 + x451 + x452 + x453 + x454 + x455 + x456
#  + x457 + x458 + x459 + x46 + x460 + x461 + x462 + x463 + x464 + x465 + x466
#  + x467 + x468 + x469 + x47 + x470 + x471 + x472 + x473 + x474 + x475 + x476
#  + x477 + x478 + x479 + x48 + x480 + x481 + x482 + x483 + x484 + x485 + x486
#  + x487 + x488 + x489 + x49 + x490 + x491 + x492 + x493 + x494 + x495 + x496
#  + x497 + x498 + x499 + x5 + x50 + x500 + x501 + x502 + x503 + x504 + x505
#  + x506 + x507 + x508 + x509 + x51 + x510 + x511 + x512 + x513 + x514 + x515
#  + x516 + x517 + x518 + x519 + x52 + x520 + x521 + x522 + x523 + x524 + x525
#  + x526 + x527 + x528 + x529 + x53 + x530 + x531 + x532 + x533 + x534 + x535
#  + x536 + x537 + x538 + x539 + x54 + x540 + x541 + x542 + x543 + x544 + x545
#  + x546 + x547 + x548 + x549 + x55 + x550 + x551 + x552 + x553 + x554 + x555
#  + x556 + x557 + x558 + x559 + x56 + x560 + x561 + x562 + x563 + x564 + x565
#  + x566 + x567 + x568 + x569 + x57 + x570 + x571 + x572 + x573 + x574 + x575
#  + x576 + x577 + x578 + x579 + x58 + x580 + x581 + x582 + x583 + x584 + x585
#  + x586 + x587 + x588 + x589 + x59 + x590 + x591 + x592 + x593 + x594 + x595
#  + x596 + x597 + x598 + x599 + x6 + x60 + x600 + x601 + x602 + x603 + x604
#  + x605 + x606 + x607 + x608 + x609 + x61 + x610 + x611 + x612 + x613 + x614
#  + x615 + x616 + x617 + x618 + x619 + x62 + x620 + x621 + x622 + x623 + x624
#  + x625 + x626 + x627 + x628 + x629 + x63 + x630 + x631 + x632 + x633 + x634
#  + x635 + x636 + x637 + x638 + x639 + x64 + x640 + x641 + x642 + x643 + x644
#  + x645 + x646 + x647 + x648 + x649 + x65 + x650 + x651 + x652 + x653 + x654
#  + x655 + x656 + x657 + x658 + x659 + x66 + x660 + x661 + x662 + x663 + x664
#  + x665 + x666 + x667 + x668 + x669 + x67 + x670 + x671 + x672 + x673 + x674
#  + x675 + x676 + x677 + x678 + x679 + x68 + x680 + x681 + x682 + x683 + x684
#  + x685 + x686 + x687 + x688 + x689 + x69 + x690 + x691 + x692 + x693 + x694
#  + x695 + x696 + x697 + x698 + x699 + x7 + x70 + x700 + x701 + x702 + x703
#  + x704 + x705 + x706 + x707 + x708 + x709 + x71 + x710 + x711 + x712 + x713
#  + x714 + x715 + x716 + x717 + x718 + x719 + x72 + x720 + x721 + x722 + x723
#  + x724 + x725 + x726 + x727 + x728 + x729 + x73 + x730 + x731 + x732 + x733
#  + x734 + x735 + x736 + x737 + x738 + x739 + x74 + x740 + x741 + x742 + x743
#  + x744 + x745 + x746 + x747 + x748 + x749 + x75 + x750 + x751 + x752 + x753
#  + x754 + x755 + x756 + x757 + x758 + x759 + x76 + x760 + x761 + x762 + x763
#  + x764 + x765 + x766 + x767 + x768 + x769 + x77 + x770 + x771 + x772 + x773
#  + x774 + x775 + x776 + x777 + x778 + x779 + x78 + x780 + x781 + x782 + x783
#  + x784 + x785 + x786 + x787 + x788 + x789 + x79 + x790 + x791 + x792 + x793
#  + x794 + x795 + x796 + x797 + x798 + x799 + x8 + x80 + x800 + x801 + x802
#  + x803 + x804 + x805 + x806 + x807 + x808 + x809 + x81 + x810 + x811 + x812
#  + x813 + x814 + x815 + x816 + x817 + x818 + x819 + x82 + x820 + x821 + x822
#  + x823 + x824 + x825 + x826 + x827 + x828 + x829 + x83 + x830 + x831 + x832
#  + x833 + x834 + x835 + x836 + x837 + x838 + x839 + x84 + x840 + x841 + x842
#  + x843 + x844 + x845 + x846 + x847 + x848 + x849 + x85 + x850 + x851 + x852
#  + x853 + x854 + x855 + x856 + x857 + x858 + x859 + x86 + x860 + x861 + x862
#  + x863 + x864 + x865 + x866 + x867 + x868 + x869 + x87 + x870 + x871 + x872
#  + x873 + x874 + x875 + x876 + x877 + x878 + x879 + x88 + x880 + x881 + x882
#  + x883 + x884 + x885 + x886 + x887 + x888 + x889 + x89 + x890 + x891 + x892
#  + x893 + x894 + x895 + x896 + x897 + x898 + x899 + x9 + x90 + x900 + x901
#  + x902 + x903 + x904 + x905 + x906 + x907 + x908 + x909 + x91 + x910 + x911
#  + x912 + x913 + x914 + x915 + x916 + x917 + x918 + x919 + x92 + x920 + x921
#  + x922 + x923 + x924 + x925 + x926 + x927 + x928 + x929 + x93 + x930 + x931
#  + x932 + x933 + x934 + x935 + x936 + x937 + x938 + x939 + x94 + x940 + x941
#  + x942 + x943 + x944 + x945 + x946 + x947 + x948 + x949 + x95 + x950 + x951
#  + x952 + x953 + x954 + x955 + x956 + x957 + x958 + x959 + x96 + x960 + x961
#  + x962 + x963 + x964 + x965 + x966 + x967 + x968 + x969 + x97 + x970 + x971
#  + x972 + x973 + x974 + x975 + x976 + x977 + x978 + x979 + x98 + x980 + x981
#  + x982 + x983 + x984 + x985 + x986 + x987 + x988 + x989 + x99 + x990 + x991
#  + x992 + x993 + x994 + x995 + x996 + x997 + x998 + x999 >= 0.001
#
# VARIABLES
# 0 <= x0 Integer
# 0 <= x1 Integer
# 0 <= x10 Integer
# 0 <= x100 Integer
# 0 <= x1000 Integer
# 0 <= x1001 Integer
# 0 <= x1002 Integer
# 0 <= x1003 Integer
# 0 <= x1004 Integer
# 0 <= x1005 Integer
# 0 <= x1006 Integer
# 0 <= x1007 Integer
# 0 <= x1008 Integer
# 0 <= x1009 Integer
# 0 <= x101 Integer
# 0 <= x1010 Integer
# 0 <= x1011 Integer
# 0 <= x1012 Integer
# 0 <= x1013 Integer
# 0 <= x1014 Integer
# 0 <= x1015 Integer
# 0 <= x1016 Integer
# 0 <= x1017 Integer
# 0 <= x1018 Integer
# 0 <= x1019 Integer
# 0 <= x102 Integer
# 0 <= x1020 Integer
# 0 <= x1021 Integer
# 0 <= x1022 Integer
# 0 <= x1023 Integer
# 0 <= x1024 Integer
# 0 <= x1025 Integer
# 0 <= x1026 Integer
# 0 <= x1027 Integer
# 0 <= x1028 Integer
# 0 <= x1029 Integer
# 0 <= x103 Integer
# 0 <= x1030 Integer
# 0 <= x1031 Integer
# 0 <= x1032 Integer
# 0 <= x1033 Integer
# 0 <= x1034 Integer
# 0 <= x1035 Integer
# 0 <= x1036 Integer
# 0 <= x1037 Integer
# 0 <= x1038 Integer
# 0 <= x1039 Integer
# 0 <= x104 Integer
# 0 <= x1040 Integer
# 0 <= x1041 Integer
# 0 <= x1042 Integer
# 0 <= x1043 Integer
# 0 <= x1044 Integer
# 0 <= x1045 Integer
# 0 <= x1046 Integer
# 0 <= x1047 Integer
# 0 <= x1048 Integer
# 0 <= x1049 Integer
# 0 <= x105 Integer
# 0 <= x1050 Integer
# 0 <= x1051 Integer
# 0 <= x1052 Integer
# 0 <= x1053 Integer
# 0 <= x1054 Integer
# 0 <= x1055 Integer
# 0 <= x1056 Integer
# 0 <= x1057 Integer
# 0 <= x1058 Integer
# 0 <= x1059 Integer
# 0 <= x106 Integer
# 0 <= x1060 Integer
# 0 <= x1061 Integer
# 0 <= x1062 Integer
# 0 <= x1063 Integer
# 0 <= x1064 Integer
# 0 <= x1065 Integer
# 0 <= x1066 Integer
# 0 <= x1067 Integer
# 0 <= x1068 Integer
# 0 <= x1069 Integer
# 0 <= x107 Integer
# 0 <= x1070 Integer
# 0 <= x1071 Integer
# 0 <= x1072 Integer
# 0 <= x1073 Integer
# 0 <= x1074 Integer
# 0 <= x1075 Integer
# 0 <= x1076 Integer
# 0 <= x1077 Integer
# 0 <= x1078 Integer
# 0 <= x1079 Integer
# 0 <= x108 Integer
# 0 <= x1080 Integer
# 0 <= x1081 Integer
# 0 <= x1082 Integer
# 0 <= x1083 Integer
# 0 <= x1084 Integer
# 0 <= x1085 Integer
# 0 <= x1086 Integer
# 0 <= x1087 Integer
# 0 <= x1088 Integer
# 0 <= x1089 Integer
# 0 <= x109 Integer
# 0 <= x1090 Integer
# 0 <= x1091 Integer
# 0 <= x1092 Integer
# 0 <= x1093 Integer
# 0 <= x1094 Integer
# 0 <= x1095 Integer
# 0 <= x1096 Integer
# 0 <= x1097 Integer
# 0 <= x1098 Integer
# 0 <= x1099 Integer
# 0 <= x11 Integer
# 0 <= x110 Integer
# 0 <= x1100 Integer
# 0 <= x1101 Integer
# 0 <= x1102 Integer
# 0 <= x1103 Integer
# 0 <= x1104 Integer
# 0 <= x1105 Integer
# 0 <= x1106 Integer
# 0 <= x1107 Integer
# 0 <= x1108 Integer
# 0 <= x1109 Integer
# 0 <= x111 Integer
# 0 <= x1110 Integer
# 0 <= x1111 Integer
# 0 <= x1112 Integer
# 0 <= x1113 Integer
# 0 <= x1114 Integer
# 0 <= x1115 Integer
# 0 <= x1116 Integer
# 0 <= x1117 Integer
# 0 <= x1118 Integer
# 0 <= x1119 Integer
# 0 <= x112 Integer
# 0 <= x1120 Integer
# 0 <= x1121 Integer
# 0 <= x1122 Integer
# 0 <= x1123 Integer
# 0 <= x1124 Integer
# 0 <= x1125 Integer
# 0 <= x1126 Integer
# 0 <= x1127 Integer
# 0 <= x1128 Integer
# 0 <= x1129 Integer
# 0 <= x113 Integer
# 0 <= x1130 Integer
# 0 <= x1131 Integer
# 0 <= x1132 Integer
# 0 <= x1133 Integer
# 0 <= x1134 Integer
# 0 <= x1135 Integer
# 0 <= x1136 Integer
# 0 <= x1137 Integer
# 0 <= x1138 Integer
# 0 <= x1139 Integer
# 0 <= x114 Integer
# 0 <= x1140 Integer
# 0 <= x115 Integer
# 0 <= x116 Integer
# 0 <= x117 Integer
# 0 <= x118 Integer
# 0 <= x119 Integer
# 0 <= x12 Integer
# 0 <= x120 Integer
# 0 <= x121 Integer
# 0 <= x122 Integer
# 0 <= x123 Integer
# 0 <= x124 Integer
# 0 <= x125 Integer
# 0 <= x126 Integer
# 0 <= x127 Integer
# 0 <= x128 Integer
# 0 <= x129 Integer
# 0 <= x13 Integer
# 0 <= x130 Integer
# 0 <= x131 Integer
# 0 <= x132 Integer
# 0 <= x133 Integer
# 0 <= x134 Integer
# 0 <= x135 Integer
# 0 <= x136 Integer
# 0 <= x137 Integer
# 0 <= x138 Integer
# 0 <= x139 Integer
# 0 <= x14 Integer
# 0 <= x140 Integer
# 0 <= x141 Integer
# 0 <= x142 Integer
# 0 <= x143 Integer
# 0 <= x144 Integer
# 0 <= x145 Integer
# 0 <= x146 Integer
# 0 <= x147 Integer
# 0 <= x148 Integer
# 0 <= x149 Integer
# 0 <= x15 Integer
# 0 <= x150 Integer
# 0 <= x151 Integer
# 0 <= x152 Integer
# 0 <= x153 Integer
# 0 <= x154 Integer
# 0 <= x155 Integer
# 0 <= x156 Integer
# 0 <= x157 Integer
# 0 <= x158 Integer
# 0 <= x159 Integer
# 0 <= x16 Integer
# 0 <= x160 Integer
# 0 <= x161 Integer
# 0 <= x162 Integer
# 0 <= x163 Integer
# 0 <= x164 Integer
# 0 <= x165 Integer
# 0 <= x166 Integer
# 0 <= x167 Integer
# 0 <= x168 Integer
# 0 <= x169 Integer
# 0 <= x17 Integer
# 0 <= x170 Integer
# 0 <= x171 Integer
# 0 <= x172 Integer
# 0 <= x173 Integer
# 0 <= x174 Integer
# 0 <= x175 Integer
# 0 <= x176 Integer
# 0 <= x177 Integer
# 0 <= x178 Integer
# 0 <= x179 Integer
# 0 <= x18 Integer
# 0 <= x180 Integer
# 0 <= x181 Integer
# 0 <= x182 Integer
# 0 <= x183 Integer
# 0 <= x184 Integer
# 0 <= x185 Integer
# 0 <= x186 Integer
# 0 <= x187 Integer
# 0 <= x188 Integer
# 0 <= x189 Integer
# 0 <= x19 Integer
# 0 <= x190 Integer
# 0 <= x191 Integer
# 0 <= x192 Integer
# 0 <= x193 Integer
# 0 <= x194 Integer
# 0 <= x195 Integer
# 0 <= x196 Integer
# 0 <= x197 Integer
# 0 <= x198 Integer
# 0 <= x199 Integer
# 0 <= x2 Integer
# 0 <= x20 Integer
# 0 <= x200 Integer
# 0 <= x201 Integer
# 0 <= x202 Integer
# 0 <= x203 Integer
# 0 <= x204 Integer
# 0 <= x205 Integer
# 0 <= x206 Integer
# 0 <= x207 Integer
# 0 <= x208 Integer
# 0 <= x209 Integer
# 0 <= x21 Integer
# 0 <= x210 Integer
# 0 <= x211 Integer
# 0 <= x212 Integer
# 0 <= x213 Integer
# 0 <= x214 Integer
# 0 <= x215 Integer
# 0 <= x216 Integer
# 0 <= x217 Integer
# 0 <= x218 Integer
# 0 <= x219 Integer
# 0 <= x22 Integer
# 0 <= x220 Integer
# 0 <= x221 Integer
# 0 <= x222 Integer
# 0 <= x223 Integer
# 0 <= x224 Integer
# 0 <= x225 Integer
# 0 <= x226 Integer
# 0 <= x227 Integer
# 0 <= x228 Integer
# 0 <= x229 Integer
# 0 <= x23 Integer
# 0 <= x230 Integer
# 0 <= x231 Integer
# 0 <= x232 Integer
# 0 <= x233 Integer
# 0 <= x234 Integer
# 0 <= x235 Integer
# 0 <= x236 Integer
# 0 <= x237 Integer
# 0 <= x238 Integer
# 0 <= x239 Integer
# 0 <= x24 Integer
# 0 <= x240 Integer
# 0 <= x241 Integer
# 0 <= x242 Integer
# 0 <= x243 Integer
# 0 <= x244 Integer
# 0 <= x245 Integer
# 0 <= x246 Integer
# 0 <= x247 Integer
# 0 <= x248 Integer
# 0 <= x249 Integer
# 0 <= x25 Integer
# 0 <= x250 Integer
# 0 <= x251 Integer
# 0 <= x252 Integer
# 0 <= x253 Integer
# 0 <= x254 Integer
# 0 <= x255 Integer
# 0 <= x256 Integer
# 0 <= x257 Integer
# 0 <= x258 Integer
# 0 <= x259 Integer
# 0 <= x26 Integer
# 0 <= x260 Integer
# 0 <= x261 Integer
# 0 <= x262 Integer
# 0 <= x263 Integer
# 0 <= x264 Integer
# 0 <= x265 Integer
# 0 <= x266 Integer
# 0 <= x267 Integer
# 0 <= x268 Integer
# 0 <= x269 Integer
# 0 <= x27 Integer
# 0 <= x270 Integer
# 0 <= x271 Integer
# 0 <= x272 Integer
# 0 <= x273 Integer
# 0 <= x274 Integer
# 0 <= x275 Integer
# 0 <= x276 Integer
# 0 <= x277 Integer
# 0 <= x278 Integer
# 0 <= x279 Integer
# 0 <= x28 Integer
# 0 <= x280 Integer
# 0 <= x281 Integer
# 0 <= x282 Integer
# 0 <= x283 Integer
# 0 <= x284 Integer
# 0 <= x285 Integer
# 0 <= x286 Integer
# 0 <= x287 Integer
# 0 <= x288 Integer
# 0 <= x289 Integer
# 0 <= x29 Integer
# 0 <= x290 Integer
# 0 <= x291 Integer
# 0 <= x292 Integer
# 0 <= x293 Integer
# 0 <= x294 Integer
# 0 <= x295 Integer
# 0 <= x296 Integer
# 0 <= x297 Integer
# 0 <= x298 Integer
# 0 <= x299 Integer
# 0 <= x3 Integer
# 0 <= x30 Integer
# 0 <= x300 Integer
# 0 <= x301 Integer
# 0 <= x302 Integer
# 0 <= x303 Integer
# 0 <= x304 Integer
# 0 <= x305 Integer
# 0 <= x306 Integer
# 0 <= x307 Integer
# 0 <= x308 Integer
# 0 <= x309 Integer
# 0 <= x31 Integer
# 0 <= x310 Integer
# 0 <= x311 Integer
# 0 <= x312 Integer
# 0 <= x313 Integer
# 0 <= x314 Integer
# 0 <= x315 Integer
# 0 <= x316 Integer
# 0 <= x317 Integer
# 0 <= x318 Integer
# 0 <= x319 Integer
# 0 <= x32 Integer
# 0 <= x320 Integer
# 0 <= x321 Integer
# 0 <= x322 Integer
# 0 <= x323 Integer
# 0 <= x324 Integer
# 0 <= x325 Integer
# 0 <= x326 Integer
# 0 <= x327 Integer
# 0 <= x328 Integer
# 0 <= x329 Integer
# 0 <= x33 Integer
# 0 <= x330 Integer
# 0 <= x331 Integer
# 0 <= x332 Integer
# 0 <= x333 Integer
# 0 <= x334 Integer
# 0 <= x335 Integer
# 0 <= x336 Integer
# 0 <= x337 Integer
# 0 <= x338 Integer
# 0 <= x339 Integer
# 0 <= x34 Integer
# 0 <= x340 Integer
# 0 <= x341 Integer
# 0 <= x342 Integer
# 0 <= x343 Integer
# 0 <= x344 Integer
# 0 <= x345 Integer
# 0 <= x346 Integer
# 0 <= x347 Integer
# 0 <= x348 Integer
# 0 <= x349 Integer
# 0 <= x35 Integer
# 0 <= x350 Integer
# 0 <= x351 Integer
# 0 <= x352 Integer
# 0 <= x353 Integer
# 0 <= x354 Integer
# 0 <= x355 Integer
# 0 <= x356 Integer
# 0 <= x357 Integer
# 0 <= x358 Integer
# 0 <= x359 Integer
# 0 <= x36 Integer
# 0 <= x360 Integer
# 0 <= x361 Integer
# 0 <= x362 Integer
# 0 <= x363 Integer
# 0 <= x364 Integer
# 0 <= x365 Integer
# 0 <= x366 Integer
# 0 <= x367 Integer
# 0 <= x368 Integer
# 0 <= x369 Integer
# 0 <= x37 Integer
# 0 <= x370 Integer
# 0 <= x371 Integer
# 0 <= x372 Integer
# 0 <= x373 Integer
# 0 <= x374 Integer
# 0 <= x375 Integer
# 0 <= x376 Integer
# 0 <= x377 Integer
# 0 <= x378 Integer
# 0 <= x379 Integer
# 0 <= x38 Integer
# 0 <= x380 Integer
# 0 <= x381 Integer
# 0 <= x382 Integer
# 0 <= x383 Integer
# 0 <= x384 Integer
# 0 <= x385 Integer
# 0 <= x386 Integer
# 0 <= x387 Integer
# 0 <= x388 Integer
# 0 <= x389 Integer
# 0 <= x39 Integer
# 0 <= x390 Integer
# 0 <= x391 Integer
# 0 <= x392 Integer
# 0 <= x393 Integer
# 0 <= x394 Integer
# 0 <= x395 Integer
# 0 <= x396 Integer
# 0 <= x397 Integer
# 0 <= x398 Integer
# 0 <= x399 Integer
# 0 <= x4 Integer
# 0 <= x40 Integer
# 0 <= x400 Integer
# 0 <= x401 Integer
# 0 <= x402 Integer
# 0 <= x403 Integer
# 0 <= x404 Integer
# 0 <= x405 Integer
# 0 <= x406 Integer
# 0 <= x407 Integer
# 0 <= x408 Integer
# 0 <= x409 Integer
# 0 <= x41 Integer
# 0 <= x410 Integer
# 0 <= x411 Integer
# 0 <= x412 Integer
# 0 <= x413 Integer
# 0 <= x414 Integer
# 0 <= x415 Integer
# 0 <= x416 Integer
# 0 <= x417 Integer
# 0 <= x418 Integer
# 0 <= x419 Integer
# 0 <= x42 Integer
# 0 <= x420 Integer
# 0 <= x421 Integer
# 0 <= x422 Integer
# 0 <= x423 Integer
# 0 <= x424 Integer
# 0 <= x425 Integer
# 0 <= x426 Integer
# 0 <= x427 Integer
# 0 <= x428 Integer
# 0 <= x429 Integer
# 0 <= x43 Integer
# 0 <= x430 Integer
# 0 <= x431 Integer
# 0 <= x432 Integer
# 0 <= x433 Integer
# 0 <= x434 Integer
# 0 <= x435 Integer
# 0 <= x436 Integer
# 0 <= x437 Integer
# 0 <= x438 Integer
# 0 <= x439 Integer
# 0 <= x44 Integer
# 0 <= x440 Integer
# 0 <= x441 Integer
# 0 <= x442 Integer
# 0 <= x443 Integer
# 0 <= x444 Integer
# 0 <= x445 Integer
# 0 <= x446 Integer
# 0 <= x447 Integer
# 0 <= x448 Integer
# 0 <= x449 Integer
# 0 <= x45 Integer
# 0 <= x450 Integer
# 0 <= x451 Integer
# 0 <= x452 Integer
# 0 <= x453 Integer
# 0 <= x454 Integer
# 0 <= x455 Integer
# 0 <= x456 Integer
# 0 <= x457 Integer
# 0 <= x458 Integer
# 0 <= x459 Integer
# 0 <= x46 Integer
# 0 <= x460 Integer
# 0 <= x461 Integer
# 0 <= x462 Integer
# 0 <= x463 Integer
# 0 <= x464 Integer
# 0 <= x465 Integer
# 0 <= x466 Integer
# 0 <= x467 Integer
# 0 <= x468 Integer
# 0 <= x469 Integer
# 0 <= x47 Integer
# 0 <= x470 Integer
# 0 <= x471 Integer
# 0 <= x472 Integer
# 0 <= x473 Integer
# 0 <= x474 Integer
# 0 <= x475 Integer
# 0 <= x476 Integer
# 0 <= x477 Integer
# 0 <= x478 Integer
# 0 <= x479 Integer
# 0 <= x48 Integer
# 0 <= x480 Integer
# 0 <= x481 Integer
# 0 <= x482 Integer
# 0 <= x483 Integer
# 0 <= x484 Integer
# 0 <= x485 Integer
# 0 <= x486 Integer
# 0 <= x487 Integer
# 0 <= x488 Integer
# 0 <= x489 Integer
# 0 <= x49 Integer
# 0 <= x490 Integer
# 0 <= x491 Integer
# 0 <= x492 Integer
# 0 <= x493 Integer
# 0 <= x494 Integer
# 0 <= x495 Integer
# 0 <= x496 Integer
# 0 <= x497 Integer
# 0 <= x498 Integer
# 0 <= x499 Integer
# 0 <= x5 Integer
# 0 <= x50 Integer
# 0 <= x500 Integer
# 0 <= x501 Integer
# 0 <= x502 Integer
# 0 <= x503 Integer
# 0 <= x504 Integer
# 0 <= x505 Integer
# 0 <= x506 Integer
# 0 <= x507 Integer
# 0 <= x508 Integer
# 0 <= x509 Integer
# 0 <= x51 Integer
# 0 <= x510 Integer
# 0 <= x511 Integer
# 0 <= x512 Integer
# 0 <= x513 Integer
# 0 <= x514 Integer
# 0 <= x515 Integer
# 0 <= x516 Integer
# 0 <= x517 Integer
# 0 <= x518 Integer
# 0 <= x519 Integer
# 0 <= x52 Integer
# 0 <= x520 Integer
# 0 <= x521 Integer
# 0 <= x522 Integer
# 0 <= x523 Integer
# 0 <= x524 Integer
# 0 <= x525 Integer
# 0 <= x526 Integer
# 0 <= x527 Integer
# 0 <= x528 Integer
# 0 <= x529 Integer
# 0 <= x53 Integer
# 0 <= x530 Integer
# 0 <= x531 Integer
# 0 <= x532 Integer
# 0 <= x533 Integer
# 0 <= x534 Integer
# 0 <= x535 Integer
# 0 <= x536 Integer
# 0 <= x537 Integer
# 0 <= x538 Integer
# 0 <= x539 Integer
# 0 <= x54 Integer
# 0 <= x540 Integer
# 0 <= x541 Integer
# 0 <= x542 Integer
# 0 <= x543 Integer
# 0 <= x544 Integer
# 0 <= x545 Integer
# 0 <= x546 Integer
# 0 <= x547 Integer
# 0 <= x548 Integer
# 0 <= x549 Integer
# 0 <= x55 Integer
# 0 <= x550 Integer
# 0 <= x551 Integer
# 0 <= x552 Integer
# 0 <= x553 Integer
# 0 <= x554 Integer
# 0 <= x555 Integer
# 0 <= x556 Integer
# 0 <= x557 Integer
# 0 <= x558 Integer
# 0 <= x559 Integer
# 0 <= x56 Integer
# 0 <= x560 Integer
# 0 <= x561 Integer
# 0 <= x562 Integer
# 0 <= x563 Integer
# 0 <= x564 Integer
# 0 <= x565 Integer
# 0 <= x566 Integer
# 0 <= x567 Integer
# 0 <= x568 Integer
# 0 <= x569 Integer
# 0 <= x57 Integer
# 0 <= x570 Integer
# 0 <= x571 Integer
# 0 <= x572 Integer
# 0 <= x573 Integer
# 0 <= x574 Integer
# 0 <= x575 Integer
# 0 <= x576 Integer
# 0 <= x577 Integer
# 0 <= x578 Integer
# 0 <= x579 Integer
# 0 <= x58 Integer
# 0 <= x580 Integer
# 0 <= x581 Integer
# 0 <= x582 Integer
# 0 <= x583 Integer
# 0 <= x584 Integer
# 0 <= x585 Integer
# 0 <= x586 Integer
# 0 <= x587 Integer
# 0 <= x588 Integer
# 0 <= x589 Integer
# 0 <= x59 Integer
# 0 <= x590 Integer
# 0 <= x591 Integer
# 0 <= x592 Integer
# 0 <= x593 Integer
# 0 <= x594 Integer
# 0 <= x595 Integer
# 0 <= x596 Integer
# 0 <= x597 Integer
# 0 <= x598 Integer
# 0 <= x599 Integer
# 0 <= x6 Integer
# 0 <= x60 Integer
# 0 <= x600 Integer
# 0 <= x601 Integer
# 0 <= x602 Integer
# 0 <= x603 Integer
# 0 <= x604 Integer
# 0 <= x605 Integer
# 0 <= x606 Integer
# 0 <= x607 Integer
# 0 <= x608 Integer
# 0 <= x609 Integer
# 0 <= x61 Integer
# 0 <= x610 Integer
# 0 <= x611 Integer
# 0 <= x612 Integer
# 0 <= x613 Integer
# 0 <= x614 Integer
# 0 <= x615 Integer
# 0 <= x616 Integer
# 0 <= x617 Integer
# 0 <= x618 Integer
# 0 <= x619 Integer
# 0 <= x62 Integer
# 0 <= x620 Integer
# 0 <= x621 Integer
# 0 <= x622 Integer
# 0 <= x623 Integer
# 0 <= x624 Integer
# 0 <= x625 Integer
# 0 <= x626 Integer
# 0 <= x627 Integer
# 0 <= x628 Integer
# 0 <= x629 Integer
# 0 <= x63 Integer
# 0 <= x630 Integer
# 0 <= x631 Integer
# 0 <= x632 Integer
# 0 <= x633 Integer
# 0 <= x634 Integer
# 0 <= x635 Integer
# 0 <= x636 Integer
# 0 <= x637 Integer
# 0 <= x638 Integer
# 0 <= x639 Integer
# 0 <= x64 Integer
# 0 <= x640 Integer
# 0 <= x641 Integer
# 0 <= x642 Integer
# 0 <= x643 Integer
# 0 <= x644 Integer
# 0 <= x645 Integer
# 0 <= x646 Integer
# 0 <= x647 Integer
# 0 <= x648 Integer
# 0 <= x649 Integer
# 0 <= x65 Integer
# 0 <= x650 Integer
# 0 <= x651 Integer
# 0 <= x652 Integer
# 0 <= x653 Integer
# 0 <= x654 Integer
# 0 <= x655 Integer
# 0 <= x656 Integer
# 0 <= x657 Integer
# 0 <= x658 Integer
# 0 <= x659 Integer
# 0 <= x66 Integer
# 0 <= x660 Integer
# 0 <= x661 Integer
# 0 <= x662 Integer
# 0 <= x663 Integer
# 0 <= x664 Integer
# 0 <= x665 Integer
# 0 <= x666 Integer
# 0 <= x667 Integer
# 0 <= x668 Integer
# 0 <= x669 Integer
# 0 <= x67 Integer
# 0 <= x670 Integer
# 0 <= x671 Integer
# 0 <= x672 Integer
# 0 <= x673 Integer
# 0 <= x674 Integer
# 0 <= x675 Integer
# 0 <= x676 Integer
# 0 <= x677 Integer
# 0 <= x678 Integer
# 0 <= x679 Integer
# 0 <= x68 Integer
# 0 <= x680 Integer
# 0 <= x681 Integer
# 0 <= x682 Integer
# 0 <= x683 Integer
# 0 <= x684 Integer
# 0 <= x685 Integer
# 0 <= x686 Integer
# 0 <= x687 Integer
# 0 <= x688 Integer
# 0 <= x689 Integer
# 0 <= x69 Integer
# 0 <= x690 Integer
# 0 <= x691 Integer
# 0 <= x692 Integer
# 0 <= x693 Integer
# 0 <= x694 Integer
# 0 <= x695 Integer
# 0 <= x696 Integer
# 0 <= x697 Integer
# 0 <= x698 Integer
# 0 <= x699 Integer
# 0 <= x7 Integer
# 0 <= x70 Integer
# 0 <= x700 Integer
# 0 <= x701 Integer
# 0 <= x702 Integer
# 0 <= x703 Integer
# 0 <= x704 Integer
# 0 <= x705 Integer
# 0 <= x706 Integer
# 0 <= x707 Integer
# 0 <= x708 Integer
# 0 <= x709 Integer
# 0 <= x71 Integer
# 0 <= x710 Integer
# 0 <= x711 Integer
# 0 <= x712 Integer
# 0 <= x713 Integer
# 0 <= x714 Integer
# 0 <= x715 Integer
# 0 <= x716 Integer
# 0 <= x717 Integer
# 0 <= x718 Integer
# 0 <= x719 Integer
# 0 <= x72 Integer
# 0 <= x720 Integer
# 0 <= x721 Integer
# 0 <= x722 Integer
# 0 <= x723 Integer
# 0 <= x724 Integer
# 0 <= x725 Integer
# 0 <= x726 Integer
# 0 <= x727 Integer
# 0 <= x728 Integer
# 0 <= x729 Integer
# 0 <= x73 Integer
# 0 <= x730 Integer
# 0 <= x731 Integer
# 0 <= x732 Integer
# 0 <= x733 Integer
# 0 <= x734 Integer
# 0 <= x735 Integer
# 0 <= x736 Integer
# 0 <= x737 Integer
# 0 <= x738 Integer
# 0 <= x739 Integer
# 0 <= x74 Integer
# 0 <= x740 Integer
# 0 <= x741 Integer
# 0 <= x742 Integer
# 0 <= x743 Integer
# 0 <= x744 Integer
# 0 <= x745 Integer
# 0 <= x746 Integer
# 0 <= x747 Integer
# 0 <= x748 Integer
# 0 <= x749 Integer
# 0 <= x75 Integer
# 0 <= x750 Integer
# 0 <= x751 Integer
# 0 <= x752 Integer
# 0 <= x753 Integer
# 0 <= x754 Integer
# 0 <= x755 Integer
# 0 <= x756 Integer
# 0 <= x757 Integer
# 0 <= x758 Integer
# 0 <= x759 Integer
# 0 <= x76 Integer
# 0 <= x760 Integer
# 0 <= x761 Integer
# 0 <= x762 Integer
# 0 <= x763 Integer
# 0 <= x764 Integer
# 0 <= x765 Integer
# 0 <= x766 Integer
# 0 <= x767 Integer
# 0 <= x768 Integer
# 0 <= x769 Integer
# 0 <= x77 Integer
# 0 <= x770 Integer
# 0 <= x771 Integer
# 0 <= x772 Integer
# 0 <= x773 Integer
# 0 <= x774 Integer
# 0 <= x775 Integer
# 0 <= x776 Integer
# 0 <= x777 Integer
# 0 <= x778 Integer
# 0 <= x779 Integer
# 0 <= x78 Integer
# 0 <= x780 Integer
# 0 <= x781 Integer
# 0 <= x782 Integer
# 0 <= x783 Integer
# 0 <= x784 Integer
# 0 <= x785 Integer
# 0 <= x786 Integer
# 0 <= x787 Integer
# 0 <= x788 Integer
# 0 <= x789 Integer
# 0 <= x79 Integer
# 0 <= x790 Integer
# 0 <= x791 Integer
# 0 <= x792 Integer
# 0 <= x793 Integer
# 0 <= x794 Integer
# 0 <= x795 Integer
# 0 <= x796 Integer
# 0 <= x797 Integer
# 0 <= x798 Integer
# 0 <= x799 Integer
# 0 <= x8 Integer
# 0 <= x80 Integer
# 0 <= x800 Integer
# 0 <= x801 Integer
# 0 <= x802 Integer
# 0 <= x803 Integer
# 0 <= x804 Integer
# 0 <= x805 Integer
# 0 <= x806 Integer
# 0 <= x807 Integer
# 0 <= x808 Integer
# 0 <= x809 Integer
# 0 <= x81 Integer
# 0 <= x810 Integer
# 0 <= x811 Integer
# 0 <= x812 Integer
# 0 <= x813 Integer
# 0 <= x814 Integer
# 0 <= x815 Integer
# 0 <= x816 Integer
# 0 <= x817 Integer
# 0 <= x818 Integer
# 0 <= x819 Integer
# 0 <= x82 Integer
# 0 <= x820 Integer
# 0 <= x821 Integer
# 0 <= x822 Integer
# 0 <= x823 Integer
# 0 <= x824 Integer
# 0 <= x825 Integer
# 0 <= x826 Integer
# 0 <= x827 Integer
# 0 <= x828 Integer
# 0 <= x829 Integer
# 0 <= x83 Integer
# 0 <= x830 Integer
# 0 <= x831 Integer
# 0 <= x832 Integer
# 0 <= x833 Integer
# 0 <= x834 Integer
# 0 <= x835 Integer
# 0 <= x836 Integer
# 0 <= x837 Integer
# 0 <= x838 Integer
# 0 <= x839 Integer
# 0 <= x84 Integer
# 0 <= x840 Integer
# 0 <= x841 Integer
# 0 <= x842 Integer
# 0 <= x843 Integer
# 0 <= x844 Integer
# 0 <= x845 Integer
# 0 <= x846 Integer
# 0 <= x847 Integer
# 0 <= x848 Integer
# 0 <= x849 Integer
# 0 <= x85 Integer
# 0 <= x850 Integer
# 0 <= x851 Integer
# 0 <= x852 Integer
# 0 <= x853 Integer
# 0 <= x854 Integer
# 0 <= x855 Integer
# 0 <= x856 Integer
# 0 <= x857 Integer
# 0 <= x858 Integer
# 0 <= x859 Integer
# 0 <= x86 Integer
# 0 <= x860 Integer
# 0 <= x861 Integer
# 0 <= x862 Integer
# 0 <= x863 Integer
# 0 <= x864 Integer
# 0 <= x865 Integer
# 0 <= x866 Integer
# 0 <= x867 Integer
# 0 <= x868 Integer
# 0 <= x869 Integer
# 0 <= x87 Integer
# 0 <= x870 Integer
# 0 <= x871 Integer
# 0 <= x872 Integer
# 0 <= x873 Integer
# 0 <= x874 Integer
# 0 <= x875 Integer
# 0 <= x876 Integer
# 0 <= x877 Integer
# 0 <= x878 Integer
# 0 <= x879 Integer
# 0 <= x88 Integer
# 0 <= x880 Integer
# 0 <= x881 Integer
# 0 <= x882 Integer
# 0 <= x883 Integer
# 0 <= x884 Integer
# 0 <= x885 Integer
# 0 <= x886 Integer
# 0 <= x887 Integer
# 0 <= x888 Integer
# 0 <= x889 Integer
# 0 <= x89 Integer
# 0 <= x890 Integer
# 0 <= x891 Integer
# 0 <= x892 Integer
# 0 <= x893 Integer
# 0 <= x894 Integer
# 0 <= x895 Integer
# 0 <= x896 Integer
# 0 <= x897 Integer
# 0 <= x898 Integer
# 0 <= x899 Integer
# 0 <= x9 Integer
# 0 <= x90 Integer
# 0 <= x900 Integer
# 0 <= x901 Integer
# 0 <= x902 Integer
# 0 <= x903 Integer
# 0 <= x904 Integer
# 0 <= x905 Integer
# 0 <= x906 Integer
# 0 <= x907 Integer
# 0 <= x908 Integer
# 0 <= x909 Integer
# 0 <= x91 Integer
# 0 <= x910 Integer
# 0 <= x911 Integer
# 0 <= x912 Integer
# 0 <= x913 Integer
# 0 <= x914 Integer
# 0 <= x915 Integer
# 0 <= x916 Integer
# 0 <= x917 Integer
# 0 <= x918 Integer
# 0 <= x919 Integer
# 0 <= x92 Integer
# 0 <= x920 Integer
# 0 <= x921 Integer
# 0 <= x922 Integer
# 0 <= x923 Integer
# 0 <= x924 Integer
# 0 <= x925 Integer
# 0 <= x926 Integer
# 0 <= x927 Integer
# 0 <= x928 Integer
# 0 <= x929 Integer
# 0 <= x93 Integer
# 0 <= x930 Integer
# 0 <= x931 Integer
# 0 <= x932 Integer
# 0 <= x933 Integer
# 0 <= x934 Integer
# 0 <= x935 Integer
# 0 <= x936 Integer
# 0 <= x937 Integer
# 0 <= x938 Integer
# 0 <= x939 Integer
# 0 <= x94 Integer
# 0 <= x940 Integer
# 0 <= x941 Integer
# 0 <= x942 Integer
# 0 <= x943 Integer
# 0 <= x944 Integer
# 0 <= x945 Integer
# 0 <= x946 Integer
# 0 <= x947 Integer
# 0 <= x948 Integer
# 0 <= x949 Integer
# 0 <= x95 Integer
# 0 <= x950 Integer
# 0 <= x951 Integer
# 0 <= x952 Integer
# 0 <= x953 Integer
# 0 <= x954 Integer
# 0 <= x955 Integer
# 0 <= x956 Integer
# 0 <= x957 Integer
# 0 <= x958 Integer
# 0 <= x959 Integer
# 0 <= x96 Integer
# 0 <= x960 Integer
# 0 <= x961 Integer
# 0 <= x962 Integer
# 0 <= x963 Integer
# 0 <= x964 Integer
# 0 <= x965 Integer
# 0 <= x966 Integer
# 0 <= x967 Integer
# 0 <= x968 Integer
# 0 <= x969 Integer
# 0 <= x97 Integer
# 0 <= x970 Integer
# 0 <= x971 Integer
# 0 <= x972 Integer
# 0 <= x973 Integer
# 0 <= x974 Integer
# 0 <= x975 Integer
# 0 <= x976 Integer
# 0 <= x977 Integer
# 0 <= x978 Integer
# 0 <= x979 Integer
# 0 <= x98 Integer
# 0 <= x980 Integer
# 0 <= x981 Integer
# 0 <= x982 Integer
# 0 <= x983 Integer
# 0 <= x984 Integer
# 0 <= x985 Integer
# 0 <= x986 Integer
# 0 <= x987 Integer
# 0 <= x988 Integer
# 0 <= x989 Integer
# 0 <= x99 Integer
# 0 <= x990 Integer
# 0 <= x991 Integer
# 0 <= x992 Integer
# 0 <= x993 Integer
# 0 <= x994 Integer
# 0 <= x995 Integer
# 0 <= x996 Integer
# 0 <= x997 Integer
# 0 <= x998 Integer
# 0 <= x999 Integer
#
# +1.0*frozenset({(3, 8), (1, 1, 2, 1), (4, 6)})+1.0*frozenset({(6, 4), (1, 1, 1, 8), (1, 1, 1, 2)})+1.0*((1, 1, 8, 1), (0, 1, 0))+1.0*((8, 3), (1,))

# %%
import cvxpy as cp
EPS = 0.5
# input
A = mat
b = np.zeros(A.shape[0])
# Construct a CVXPY problem
x = cp.Variable(A.shape[1], integer=True)
objective = cp.Minimize(cp.sum_squares(x))
constraints = []
for var in x:
    constraints.append(var >= 0)
constraints.append(A@x==b)
constraints.append(cp.sum(x) >= EPS)
prob = cp.Problem(objective,constraints)
prob.solve()
resultList = pantList+eyeList
resultStr = ""
for i in range(len(x.value)):
    if round(x.value[i]) != 0.0:
        resultStr += "+" + str(round(x.value[i])) + "*" + str(resultList[i])
print(resultStr)
# Out:
# +1.0*frozenset({(3, 8), (1, 2, 5, 1), (1, 2, 1, 4)})+1.0*frozenset({(1, 1, 1, 8), (2, 1, 4, 1), (1, 5, 2, 1)})+1.0*((1, 1, 8, 1), (0, 1, 0))+1.0*((8, 3), (1,))
